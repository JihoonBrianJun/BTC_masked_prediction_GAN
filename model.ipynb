# %%
import numpy as np
import pandas as pd
import os
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset
from torch.autograd import Variable

# %%
# Load preprocessed raw data

raw_df = pd.read_csv('input_data_2021-12.csv', names = ['ud','ma','volume','behav'])
raw_df = raw_df.astype('float32')

# %%
raw_df
# Out:
#               ud          ma    volume     behav
# 0     -25.280001  197.162994  3.077591  0.425532
# 1      28.860001  180.410995  3.026688  0.568965
# 2      13.400000  163.350006  2.462048  0.543478
# 3     -34.180000  147.085007  2.963388  0.593750
# 4      24.379999  137.246506  2.557441  0.529412
# ...          ...         ...       ...       ...
# 44015 -33.099998  -61.709000  2.811403  0.230769
# 44016  -2.690000  -72.959503  2.919086  0.250000
# 44017  -1.650000  -86.261002  3.485018  0.125000
# 44018 -62.020000  -99.489502  3.991151  0.551724
# 44019  30.600000 -113.761497  3.140803  0.516129
#
# [44020 rows x 4 columns]

# %%
# Min-Max Scaling for each features
# Convert "behav" column's scale from 0~1 to -1~1 (This is target feature)
# Further scale conversion of "behav" column is for the prevention of the skewed training of the model

df = raw_df.copy()
df = (df - raw_df.min(axis=0)) / (raw_df.max(axis=0)-raw_df.min(axis=0))
df['behav'] = 2*df['behav']-1

# %%
df
# Out:
#              ud        ma    volume     behav
# 0      0.415733  0.828605  0.436649 -0.169453
# 1      0.596200  0.800685  0.424811  0.122537
# 2      0.544667  0.772250  0.293500  0.070652
# 3      0.386067  0.745142  0.410090  0.172991
# 4      0.581267  0.728744  0.315684  0.042017
# ...         ...       ...       ...       ...
# 44015  0.389667  0.397152  0.374745 -0.565934
# 44016  0.491033  0.378401  0.399787 -0.526786
# 44017  0.494500  0.356232  0.531400 -0.781250
# 44018  0.293267  0.334184  0.649105  0.087438
# 44019  0.602000  0.310398  0.451349  0.014977
#
# [44020 rows x 4 columns]

# %%
# Median value for each columns

threshold = torch.tensor((raw_df[['ud','ma','volume']].median(axis=0)- raw_df[['ud','ma','volume']].min(axis=0))/ (raw_df[['ud','ma','volume']].max(axis=0)-raw_df[['ud','ma','volume']].min(axis=0))).float()
print(threshold)
# Out:
# tensor([0.5000, 0.4996, 0.3838])

# %%
# torch.tensor version of df

data_list = torch.tensor(df.values).float()
print(data_list)
# Out:
# tensor([[ 0.4157,  0.8286,  0.4366, -0.1695],
#         [ 0.5962,  0.8007,  0.4248,  0.1225],
#         [ 0.5447,  0.7722,  0.2935,  0.0707],
#         ...,
#         [ 0.4945,  0.3562,  0.5314, -0.7812],
#         [ 0.2933,  0.3342,  0.6491,  0.0874],
#         [ 0.6020,  0.3104,  0.4513,  0.0150]])

# %% [markdown]
# # GAN Model 1 (Only linear layers)

# %% [markdown]
# Code for this model is only for demonstration.
#
# This model does not include testing process

# %%
image_width = 20    # Time horizon for each image (20 minutes)
image_depth = 3     # View each feature as each channel

# Obtain dataset by applying sliding window of size 20 to data_list 
data_set = torch.zeros((data_list.size()[0] - image_width + 1, image_width, data_list.size()[1]))
for i in range(data_list.size()[0] - image_width + 1):
  data_set[i,:,:] = data_list[i:i+image_width,:]
print(data_set.size())
# Out:
# torch.Size([44001, 20, 4])

# %%
image_set = data_set[:,:,:3]   # Input features
latent_set = data_set[:,:,3]   # Target feaure

print(image_set.size())
print(latent_set.size())
# Out:
# torch.Size([44001, 20, 3])
# torch.Size([44001, 20])

# %%
# Choose training and validation data randomly (95% for training, 5% for Validation)
rand_idx = np.random.choice(data_set.size()[0],size=data_set.size()[0], replace=False)
train_idx = rand_idx[:(data_set.size()[0]//20)*19]
test_idx = rand_idx[(data_set.size()[0]//20)*19:]

train_image = image_set[train_idx,:,:]  # Train input features
train_latent = latent_set[train_idx,:]  # Train targer feature
test_image = image_set[test_idx,:,:]    # Validation input features
test_latent = latent_set[test_idx,:]    # Validation target feature

print(train_image.size())
print(train_latent.size())
print(test_image.size())
print(test_latent.size())
# Out:
# torch.Size([41800, 20, 3])
# torch.Size([41800, 20])
# torch.Size([2201, 20, 3])
# torch.Size([2201, 20])

# %%
# Put above training and validation data into Dataloader of Pytorch

train_set = TensorDataset(train_image, train_latent)
test_set = TensorDataset(test_image, test_latent)

bs = 16
train_loader = torch.utils.data.DataLoader(dataset=train_set, batch_size=bs, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_set, batch_size=1, shuffle=False)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class Generator(nn.Module):
    '''
    4 linear layers with leaky_relu activation for first 3 layers, and tanh activation for last one.
    Tanh activation at last layer restricts the range of output value to be -1 ~ 1
    This is for the range matching with the target feature ("behav" column)
    '''
    def __init__(self, g_input_dim, g_output_dim):
        super(Generator, self).__init__()       
        self.fc1 = nn.Linear(g_input_dim, 40)
        self.fc2 = nn.Linear(self.fc1.out_features, 60)
        self.fc3 = nn.Linear(self.fc2.out_features, 80)
        self.fc4 = nn.Linear(self.fc3.out_features, g_output_dim)
    
    # forward method
    def forward(self, x): 
        x = F.leaky_relu(self.fc1(x), 0.2)
        x = F.leaky_relu(self.fc2(x), 0.2)
        x = F.leaky_relu(self.fc3(x), 0.2)
        return torch.tanh(self.fc4(x))
    
    
class Discriminator(nn.Module):
    '''
    4 linear layers with leaky_relu activation and dropout for first 3 layers, and sigmoid activation for last one.
    Sigmoid activation at last layer restricts the range of output value to be 0 ~ 1
    Discriminator generally returns the probability of Generator being fake, so it returns pseudo-probabilistic values
    '''    
    def __init__(self, d_input_dim):
        super(Discriminator, self).__init__()
        self.fc1 = nn.Linear(d_input_dim, 40)
        self.fc2 = nn.Linear(self.fc1.out_features, self.fc1.out_features//2)
        self.fc3 = nn.Linear(self.fc2.out_features, self.fc2.out_features//2)
        self.fc4 = nn.Linear(self.fc3.out_features, 1)
    
    # forward method
    def forward(self, x):
        x = F.leaky_relu(self.fc1(x), 0.2)
        x = F.dropout(x, 0.3)
        x = F.leaky_relu(self.fc2(x), 0.2)
        x = F.dropout(x, 0.3)
        x = F.leaky_relu(self.fc3(x), 0.2)
        x = F.dropout(x, 0.3)
        return torch.sigmoid(self.fc4(x))
    

z_dim = image_width

G = Generator(g_input_dim = z_dim, g_output_dim = (image_width)*(image_depth)).to(device)
D = Discriminator((image_width)*(image_depth)).to(device)

G_optimizer = optim.Adam(G.parameters(), lr = 0.0000035)
D_optimizer = optim.Adam(D.parameters(), lr = 0.0000035)


# Training process
n_epoch = 100
for epoch in range(n_epoch):           
    D_losses, G_losses = [], []
    for x, y in train_loader:
        D.zero_grad()
        x_real = x.view(-1,(image_width)*(image_depth)).to(device)
        D_real_loss = torch.mean(torch.log(D(x_real)))
        Z = y.view(-1,image_width).to(device)
        D_fake_loss = torch.mean(torch.log(1-D(G(Z))))
        D_loss = -(D_real_loss + D_fake_loss)
        D_loss.backward()
        D_optimizer.step()
        D_losses.append(D_loss.data.item())
        
        G.zero_grad()
        Z = y.view(-1,image_width).to(device)
        G_loss = torch.mean(torch.log(1-D(G(Z))))
        G_loss.backward()
        G_optimizer.step()
        G_losses.append(G_loss.data.item())

    D_losses, G_losses = torch.tensor(D_losses), torch.tensor(G_losses) 
    print('[%d/%d]: loss_d: %.3f, loss_g: %.3f' % (epoch, n_epoch, torch.mean(D_losses), torch.mean(G_losses)))
# Out:
# [0/100]: loss_d: 1.381, loss_g: -0.656
# [1/100]: loss_d: 1.320, loss_g: -0.668
# [2/100]: loss_d: 1.311, loss_g: -0.731
# [3/100]: loss_d: 1.379, loss_g: -0.786
# [4/100]: loss_d: 1.409, loss_g: -0.732
# [5/100]: loss_d: 1.410, loss_g: -0.666
# [6/100]: loss_d: 1.403, loss_g: -0.633
# [7/100]: loss_d: 1.394, loss_g: -0.630
# [8/100]: loss_d: 1.387, loss_g: -0.641
# [9/100]: loss_d: 1.387, loss_g: -0.655
# [10/100]: loss_d: 1.391, loss_g: -0.660
# [11/100]: loss_d: 1.392, loss_g: -0.666
# [12/100]: loss_d: 1.388, loss_g: -0.675
# [13/100]: loss_d: 1.389, loss_g: -0.678
# [14/100]: loss_d: 1.386, loss_g: -0.678
# [15/100]: loss_d: 1.385, loss_g: -0.684
# [16/100]: loss_d: 1.390, loss_g: -0.689
# [17/100]: loss_d: 1.390, loss_g: -0.695
# [18/100]: loss_d: 1.385, loss_g: -0.696
# [19/100]: loss_d: 1.388, loss_g: -0.694
# [20/100]: loss_d: 1.386, loss_g: -0.689
# [21/100]: loss_d: 1.389, loss_g: -0.690
# [22/100]: loss_d: 1.385, loss_g: -0.700
# [23/100]: loss_d: 1.391, loss_g: -0.707
# [24/100]: loss_d: 1.387, loss_g: -0.691
# [25/100]: loss_d: 1.387, loss_g: -0.684
# [26/100]: loss_d: 1.386, loss_g: -0.694
# [27/100]: loss_d: 1.390, loss_g: -0.700
# [28/100]: loss_d: 1.388, loss_g: -0.693
# [29/100]: loss_d: 1.386, loss_g: -0.687
# [30/100]: loss_d: 1.387, loss_g: -0.690
# [31/100]: loss_d: 1.383, loss_g: -0.703
# [32/100]: loss_d: 1.391, loss_g: -0.704
# [33/100]: loss_d: 1.387, loss_g: -0.690
# [34/100]: loss_d: 1.387, loss_g: -0.688
# [35/100]: loss_d: 1.386, loss_g: -0.695
# [36/100]: loss_d: 1.388, loss_g: -0.699
# [37/100]: loss_d: 1.386, loss_g: -0.692
# [38/100]: loss_d: 1.388, loss_g: -0.691
# [39/100]: loss_d: 1.387, loss_g: -0.695
# [40/100]: loss_d: 1.388, loss_g: -0.695
# [41/100]: loss_d: 1.386, loss_g: -0.691
# [42/100]: loss_d: 1.387, loss_g: -0.696
# [43/100]: loss_d: 1.387, loss_g: -0.695
# [44/100]: loss_d: 1.388, loss_g: -0.689
# [45/100]: loss_d: 1.384, loss_g: -0.690
# [46/100]: loss_d: 1.390, loss_g: -0.699
# [47/100]: loss_d: 1.387, loss_g: -0.692
# [48/100]: loss_d: 1.388, loss_g: -0.692
# [49/100]: loss_d: 1.383, loss_g: -0.693
# [50/100]: loss_d: 1.389, loss_g: -0.701
# [51/100]: loss_d: 1.389, loss_g: -0.692
# [52/100]: loss_d: 1.386, loss_g: -0.688
# [53/100]: loss_d: 1.387, loss_g: -0.692
# [54/100]: loss_d: 1.385, loss_g: -0.693
# [55/100]: loss_d: 1.388, loss_g: -0.696
# [56/100]: loss_d: 1.387, loss_g: -0.693
# [57/100]: loss_d: 1.384, loss_g: -0.694
# [58/100]: loss_d: 1.389, loss_g: -0.694
# [59/100]: loss_d: 1.386, loss_g: -0.690
# [60/100]: loss_d: 1.388, loss_g: -0.694
# [61/100]: loss_d: 1.387, loss_g: -0.693
# [62/100]: loss_d: 1.387, loss_g: -0.695
# [63/100]: loss_d: 1.387, loss_g: -0.693
# [64/100]: loss_d: 1.387, loss_g: -0.692
# [65/100]: loss_d: 1.387, loss_g: -0.693
# [66/100]: loss_d: 1.386, loss_g: -0.693
# [67/100]: loss_d: 1.387, loss_g: -0.694
# [68/100]: loss_d: 1.387, loss_g: -0.694
# [69/100]: loss_d: 1.386, loss_g: -0.690
# [70/100]: loss_d: 1.387, loss_g: -0.693
# [71/100]: loss_d: 1.387, loss_g: -0.695
# [72/100]: loss_d: 1.387, loss_g: -0.693
# [73/100]: loss_d: 1.387, loss_g: -0.693
# [74/100]: loss_d: 1.386, loss_g: -0.693
# [75/100]: loss_d: 1.387, loss_g: -0.694
# [76/100]: loss_d: 1.387, loss_g: -0.694
# [77/100]: loss_d: 1.387, loss_g: -0.692
# [78/100]: loss_d: 1.386, loss_g: -0.694
# [79/100]: loss_d: 1.386, loss_g: -0.693
# [80/100]: loss_d: 1.386, loss_g: -0.693
# [81/100]: loss_d: 1.387, loss_g: -0.694
# [82/100]: loss_d: 1.387, loss_g: -0.693
# [83/100]: loss_d: 1.387, loss_g: -0.693
# [84/100]: loss_d: 1.387, loss_g: -0.694
# [85/100]: loss_d: 1.387, loss_g: -0.693
# [86/100]: loss_d: 1.387, loss_g: -0.693
# [87/100]: loss_d: 1.387, loss_g: -0.694
# [88/100]: loss_d: 1.387, loss_g: -0.693
# [89/100]: loss_d: 1.387, loss_g: -0.693
# [90/100]: loss_d: 1.386, loss_g: -0.693
# [91/100]: loss_d: 1.385, loss_g: -0.696
# [92/100]: loss_d: 1.388, loss_g: -0.695
# [93/100]: loss_d: 1.387, loss_g: -0.692
# [94/100]: loss_d: 1.388, loss_g: -0.694
# [95/100]: loss_d: 1.384, loss_g: -0.694
# [96/100]: loss_d: 1.389, loss_g: -0.695
# [97/100]: loss_d: 1.381, loss_g: -0.693
# [98/100]: loss_d: 1.392, loss_g: -0.696
# [99/100]: loss_d: 1.384, loss_g: -0.689

# %%
# Validation process
# This includes the masked prediction process

loss_list = []
pred_list = torch.zeros(len(test_loader), 1, image_width, image_depth)
orig_list = torch.zeros(len(test_loader), 1, image_width, image_depth)

for iter, (images, latents) in enumerate(test_loader):
  image_num = images.size()[0]
  original = images.clone()
  prediction = torch.zeros(image_num, image_width, image_depth)
  
  
  # Masking process for the last time index (last 1 minute) of the image
  # Masking is done by setting values equal to the median values of the whole data
  mask = torch.ones_like(images, dtype=torch.bool)
  mask[:,-1,:] = 0
  images[mask.logical_not()] = threshold * torch.ones_like(images[mask.logical_not()])
  X = images.clone().requires_grad_(True)
  
  
  objective_list = []
  
  for i in range(100):    
    Z = latents.view(-1,image_width).to(device)
    objective = torch.mean(torch.log(D(X.view(-1,(image_width)*(image_depth)).to(device)))+torch.log(1-D(G(Z))))
    objective.backward()
    objective_list.append(objective)
    X_grad = X.grad.requires_grad_(False)
    X = X.requires_grad_(False)
    projection = torch.clamp(X.data[mask.logical_not()] - 0.05*X_grad[mask.logical_not()], min=0, max=1)
    X.data[mask.logical_not()] = projection
    X.requires_grad_(True)
  prediction = X
  pred_list[iter,:,:,:] = prediction.requires_grad_(False)
  orig_list[iter,:,:,:] = original
  
  # Loss is computed for the last time index (masked index) only
  loss = torch.mean(torch.square(prediction[:,-1,0] - original[:,-1,0]))
  loss_list.append(loss)
  
  print(str(iter)+'th iter done')
  
pred_list = torch.squeeze(pred_list, 1).numpy()
orig_list = torch.squeeze(orig_list, 1).numpy()
loss_list = torch.tensor(loss_list)
print(torch.sqrt(loss_list.mean()))
# Out:
# 0th iter done
# 1th iter done
# 2th iter done
# 3th iter done
# 4th iter done
# 5th iter done
# 6th iter done
# 7th iter done
# 8th iter done
# 9th iter done
# 10th iter done
# 11th iter done
# 12th iter done
# 13th iter done
# 14th iter done
# 15th iter done
# 16th iter done
# 17th iter done
# 18th iter done
# 19th iter done
# 20th iter done
# 21th iter done
# 22th iter done
# 23th iter done
# 24th iter done
# 25th iter done
# 26th iter done
# 27th iter done
# 28th iter done
# 29th iter done
# 30th iter done
# 31th iter done
# 32th iter done
# 33th iter done
# 34th iter done
# 35th iter done
# 36th iter done
# 37th iter done
# 38th iter done
# 39th iter done
# 40th iter done
# 41th iter done
# 42th iter done
# 43th iter done
# 44th iter done
# 45th iter done
# 46th iter done
# 47th iter done
# 48th iter done
# 49th iter done
# 50th iter done
# 51th iter done
# 52th iter done
# 53th iter done
# 54th iter done
# 55th iter done
# 56th iter done
# 57th iter done
# 58th iter done
# 59th iter done
# 60th iter done
# 61th iter done
# 62th iter done
# 63th iter done
# 64th iter done
# 65th iter done
# 66th iter done
# 67th iter done
# 68th iter done
# 69th iter done
# 70th iter done
# 71th iter done
# 72th iter done
# 73th iter done
# 74th iter done
# 75th iter done
# 76th iter done
# 77th iter done
# 78th iter done
# 79th iter done
# 80th iter done
# 81th iter done
# 82th iter done
# 83th iter done
# 84th iter done
# 85th iter done
# 86th iter done
# 87th iter done
# 88th iter done
# 89th iter done
# 90th iter done
# 91th iter done
# 92th iter done
# 93th iter done
# 94th iter done
# 95th iter done
# 96th iter done
# 97th iter done
# 98th iter done
# 99th iter done
# 100th iter done
# 101th iter done
# 102th iter done
# 103th iter done
# 104th iter done
# 105th iter done
# 106th iter done
# 107th iter done
# 108th iter done
# 109th iter done
# 110th iter done
# 111th iter done
# 112th iter done
# 113th iter done
# 114th iter done
# 115th iter done
# 116th iter done
# 117th iter done
# 118th iter done
# 119th iter done
# 120th iter done
# 121th iter done
# 122th iter done
# 123th iter done
# 124th iter done
# 125th iter done
# 126th iter done
# 127th iter done
# 128th iter done
# 129th iter done
# 130th iter done
# 131th iter done
# 132th iter done
# 133th iter done
# 134th iter done
# 135th iter done
# 136th iter done
# 137th iter done
# 138th iter done
# 139th iter done
# 140th iter done
# 141th iter done
# 142th iter done
# 143th iter done
# 144th iter done
# 145th iter done
# 146th iter done
# 147th iter done
# 148th iter done
# 149th iter done
# 150th iter done
# 151th iter done
# 152th iter done
# 153th iter done
# 154th iter done
# 155th iter done
# 156th iter done
# 157th iter done
# 158th iter done
# 159th iter done
# 160th iter done
# 161th iter done
# 162th iter done
# 163th iter done
# 164th iter done
# 165th iter done
# 166th iter done
# 167th iter done
# 168th iter done
# 169th iter done
# 170th iter done
# 171th iter done
# 172th iter done
# 173th iter done
# 174th iter done
# 175th iter done
# 176th iter done
# 177th iter done
# 178th iter done
# 179th iter done
# 180th iter done
# 181th iter done
# 182th iter done
# 183th iter done
# 184th iter done
# 185th iter done
# 186th iter done
# 187th iter done
# 188th iter done
# 189th iter done
# 190th iter done
# 191th iter done
# 192th iter done
# 193th iter done
# 194th iter done
# 195th iter done
# 196th iter done
# 197th iter done
# 198th iter done
# 199th iter done
# 200th iter done
# 201th iter done
# 202th iter done
# 203th iter done
# 204th iter done
# 205th iter done
# 206th iter done
# 207th iter done
# 208th iter done
# 209th iter done
# 210th iter done
# 211th iter done
# 212th iter done
# 213th iter done
# 214th iter done
# 215th iter done
# 216th iter done
# 217th iter done
# 218th iter done
# 219th iter done
# 220th iter done
# 221th iter done
# 222th iter done
# 223th iter done
# 224th iter done
# 225th iter done
# 226th iter done
# 227th iter done
# 228th iter done
# 229th iter done
# 230th iter done
# 231th iter done
# 232th iter done
# 233th iter done
# 234th iter done
# 235th iter done
# 236th iter done
# 237th iter done
# 238th iter done
# 239th iter done
# 240th iter done
# 241th iter done
# 242th iter done
# 243th iter done
# 244th iter done
# 245th iter done
# 246th iter done
# 247th iter done
# 248th iter done
# 249th iter done
# 250th iter done
# 251th iter done
# 252th iter done
# 253th iter done
# 254th iter done
# 255th iter done
# 256th iter done
# 257th iter done
# 258th iter done
# 259th iter done
# 260th iter done
# 261th iter done
# 262th iter done
# 263th iter done
# 264th iter done
# 265th iter done
# 266th iter done
# 267th iter done
# 268th iter done
# 269th iter done
# 270th iter done
# 271th iter done
# 272th iter done
# 273th iter done
# 274th iter done
# 275th iter done
# 276th iter done
# 277th iter done
# 278th iter done
# 279th iter done
# 280th iter done
# 281th iter done
# 282th iter done
# 283th iter done
# 284th iter done
# 285th iter done
# 286th iter done
# 287th iter done
# 288th iter done
# 289th iter done
# 290th iter done
# 291th iter done
# 292th iter done
# 293th iter done
# 294th iter done
# 295th iter done
# 296th iter done
# 297th iter done
# 298th iter done
# 299th iter done
# 300th iter done
# 301th iter done
# 302th iter done
# 303th iter done
# 304th iter done
# 305th iter done
# 306th iter done
# 307th iter done
# 308th iter done
# 309th iter done
# 310th iter done
# 311th iter done
# 312th iter done
# 313th iter done
# 314th iter done
# 315th iter done
# 316th iter done
# 317th iter done
# 318th iter done
# 319th iter done
# 320th iter done
# 321th iter done
# 322th iter done
# 323th iter done
# 324th iter done
# 325th iter done
# 326th iter done
# 327th iter done
# 328th iter done
# 329th iter done
# 330th iter done
# 331th iter done
# 332th iter done
# 333th iter done
# 334th iter done
# 335th iter done
# 336th iter done
# 337th iter done
# 338th iter done
# 339th iter done
# 340th iter done
# 341th iter done
# 342th iter done
# 343th iter done
# 344th iter done
# 345th iter done
# 346th iter done
# 347th iter done
# 348th iter done
# 349th iter done
# 350th iter done
# 351th iter done
# 352th iter done
# 353th iter done
# 354th iter done
# 355th iter done
# 356th iter done
# 357th iter done
# 358th iter done
# 359th iter done
# 360th iter done
# 361th iter done
# 362th iter done
# 363th iter done
# 364th iter done
# 365th iter done
# 366th iter done
# 367th iter done
# 368th iter done
# 369th iter done
# 370th iter done
# 371th iter done
# 372th iter done
# 373th iter done
# 374th iter done
# 375th iter done
# 376th iter done
# 377th iter done
# 378th iter done
# 379th iter done
# 380th iter done
# 381th iter done
# 382th iter done
# 383th iter done
# 384th iter done
# 385th iter done
# 386th iter done
# 387th iter done
# 388th iter done
# 389th iter done
# 390th iter done
# 391th iter done
# 392th iter done
# 393th iter done
# 394th iter done
# 395th iter done
# 396th iter done
# 397th iter done
# 398th iter done
# 399th iter done
# 400th iter done
# 401th iter done
# 402th iter done
# 403th iter done
# 404th iter done
# 405th iter done
# 406th iter done
# 407th iter done
# 408th iter done
# 409th iter done
# 410th iter done
# 411th iter done
# 412th iter done
# 413th iter done
# 414th iter done
# 415th iter done
# 416th iter done
# 417th iter done
# 418th iter done
# 419th iter done
# 420th iter done
# 421th iter done
# 422th iter done
# 423th iter done
# 424th iter done
# 425th iter done
# 426th iter done
# 427th iter done
# 428th iter done
# 429th iter done
# 430th iter done
# 431th iter done
# 432th iter done
# 433th iter done
# 434th iter done
# 435th iter done
# 436th iter done
# 437th iter done
# 438th iter done
# 439th iter done
# 440th iter done
# 441th iter done
# 442th iter done
# 443th iter done
# 444th iter done
# 445th iter done
# 446th iter done
# 447th iter done
# 448th iter done
# 449th iter done
# 450th iter done
# 451th iter done
# 452th iter done
# 453th iter done
# 454th iter done
# 455th iter done
# 456th iter done
# 457th iter done
# 458th iter done
# 459th iter done
# 460th iter done
# 461th iter done
# 462th iter done
# 463th iter done
# 464th iter done
# 465th iter done
# 466th iter done
# 467th iter done
# 468th iter done
# 469th iter done
# 470th iter done
# 471th iter done
# 472th iter done
# 473th iter done
# 474th iter done
# 475th iter done
# 476th iter done
# 477th iter done
# 478th iter done
# 479th iter done
# 480th iter done
# 481th iter done
# 482th iter done
# 483th iter done
# 484th iter done
# 485th iter done
# 486th iter done
# 487th iter done
# 488th iter done
# 489th iter done
# 490th iter done
# 491th iter done
# 492th iter done
# 493th iter done
# 494th iter done
# 495th iter done
# 496th iter done
# 497th iter done
# 498th iter done
# 499th iter done
# 500th iter done
# 501th iter done
# 502th iter done
# 503th iter done
# 504th iter done
# 505th iter done
# 506th iter done
# 507th iter done
# 508th iter done
# 509th iter done
# 510th iter done
# 511th iter done
# 512th iter done
# 513th iter done
# 514th iter done
# 515th iter done
# 516th iter done
# 517th iter done
# 518th iter done
# 519th iter done
# 520th iter done
# 521th iter done
# 522th iter done
# 523th iter done
# 524th iter done
# 525th iter done
# 526th iter done
# 527th iter done
# 528th iter done
# 529th iter done
# 530th iter done
# 531th iter done
# 532th iter done
# 533th iter done
# 534th iter done
# 535th iter done
# 536th iter done
# 537th iter done
# 538th iter done
# 539th iter done
# 540th iter done
# 541th iter done
# 542th iter done
# 543th iter done
# 544th iter done
# 545th iter done
# 546th iter done
# 547th iter done
# 548th iter done
# 549th iter done
# 550th iter done
# 551th iter done
# 552th iter done
# 553th iter done
# 554th iter done
# 555th iter done
# 556th iter done
# 557th iter done
# 558th iter done
# 559th iter done
# 560th iter done
# 561th iter done
# 562th iter done
# 563th iter done
# 564th iter done
# 565th iter done
# 566th iter done
# 567th iter done
# 568th iter done
# 569th iter done
# 570th iter done
# 571th iter done
# 572th iter done
# 573th iter done
# 574th iter done
# 575th iter done
# 576th iter done
# 577th iter done
# 578th iter done
# 579th iter done
# 580th iter done
# 581th iter done
# 582th iter done
# 583th iter done
# 584th iter done
# 585th iter done
# 586th iter done
# 587th iter done
# 588th iter done
# 589th iter done
# 590th iter done
# 591th iter done
# 592th iter done
# 593th iter done
# 594th iter done
# 595th iter done
# 596th iter done
# 597th iter done
# 598th iter done
# 599th iter done
# 600th iter done
# 601th iter done
# 602th iter done
# 603th iter done
# 604th iter done
# 605th iter done
# 606th iter done
# 607th iter done
# 608th iter done
# 609th iter done
# 610th iter done
# 611th iter done
# 612th iter done
# 613th iter done
# 614th iter done
# 615th iter done
# 616th iter done
# 617th iter done
# 618th iter done
# 619th iter done
# 620th iter done
# 621th iter done
# 622th iter done
# 623th iter done
# 624th iter done
# 625th iter done
# 626th iter done
# 627th iter done
# 628th iter done
# 629th iter done
# 630th iter done
# 631th iter done
# 632th iter done
# 633th iter done
# 634th iter done
# 635th iter done
# 636th iter done
# 637th iter done
# 638th iter done
# 639th iter done
# 640th iter done
# 641th iter done
# 642th iter done
# 643th iter done
# 644th iter done
# 645th iter done
# 646th iter done
# 647th iter done
# 648th iter done
# 649th iter done
# 650th iter done
# 651th iter done
# 652th iter done
# 653th iter done
# 654th iter done
# 655th iter done
# 656th iter done
# 657th iter done
# 658th iter done
# 659th iter done
# 660th iter done
# 661th iter done
# 662th iter done
# 663th iter done
# 664th iter done
# 665th iter done
# 666th iter done
# 667th iter done
# 668th iter done
# 669th iter done
# 670th iter done
# 671th iter done
# 672th iter done
# 673th iter done
# 674th iter done
# 675th iter done
# 676th iter done
# 677th iter done
# 678th iter done
# 679th iter done
# 680th iter done
# 681th iter done
# 682th iter done
# 683th iter done
# 684th iter done
# 685th iter done
# 686th iter done
# 687th iter done
# 688th iter done
# 689th iter done
# 690th iter done
# 691th iter done
# 692th iter done
# 693th iter done
# 694th iter done
# 695th iter done
# 696th iter done
# 697th iter done
# 698th iter done
# 699th iter done
# 700th iter done
# 701th iter done
# 702th iter done
# 703th iter done
# 704th iter done
# 705th iter done
# 706th iter done
# 707th iter done
# 708th iter done
# 709th iter done
# 710th iter done
# 711th iter done
# 712th iter done
# 713th iter done
# 714th iter done
# 715th iter done
# 716th iter done
# 717th iter done
# 718th iter done
# 719th iter done
# 720th iter done
# 721th iter done
# 722th iter done
# 723th iter done
# 724th iter done
# 725th iter done
# 726th iter done
# 727th iter done
# 728th iter done
# 729th iter done
# 730th iter done
# 731th iter done
# 732th iter done
# 733th iter done
# 734th iter done
# 735th iter done
# 736th iter done
# 737th iter done
# 738th iter done
# 739th iter done
# 740th iter done
# 741th iter done
# 742th iter done
# 743th iter done
# 744th iter done
# 745th iter done
# 746th iter done
# 747th iter done
# 748th iter done
# 749th iter done
# 750th iter done
# 751th iter done
# 752th iter done
# 753th iter done
# 754th iter done
# 755th iter done
# 756th iter done
# 757th iter done
# 758th iter done
# 759th iter done
# 760th iter done
# 761th iter done
# 762th iter done
# 763th iter done
# 764th iter done
# 765th iter done
# 766th iter done
# 767th iter done
# 768th iter done
# 769th iter done
# 770th iter done
# 771th iter done
# 772th iter done
# 773th iter done
# 774th iter done
# 775th iter done
# 776th iter done
# 777th iter done
# 778th iter done
# 779th iter done
# 780th iter done
# 781th iter done
# 782th iter done
# 783th iter done
# 784th iter done
# 785th iter done
# 786th iter done
# 787th iter done
# 788th iter done
# 789th iter done
# 790th iter done
# 791th iter done
# 792th iter done
# 793th iter done
# 794th iter done
# 795th iter done
# 796th iter done
# 797th iter done
# 798th iter done
# 799th iter done
# 800th iter done
# 801th iter done
# 802th iter done
# 803th iter done
# 804th iter done
# 805th iter done
# 806th iter done
# 807th iter done
# 808th iter done
# 809th iter done
# 810th iter done
# 811th iter done
# 812th iter done
# 813th iter done
# 814th iter done
# 815th iter done
# 816th iter done
# 817th iter done
# 818th iter done
# 819th iter done
# 820th iter done
# 821th iter done
# 822th iter done
# 823th iter done
# 824th iter done
# 825th iter done
# 826th iter done
# 827th iter done
# 828th iter done
# 829th iter done
# 830th iter done
# 831th iter done
# 832th iter done
# 833th iter done
# 834th iter done
# 835th iter done
# 836th iter done
# 837th iter done
# 838th iter done
# 839th iter done
# 840th iter done
# 841th iter done
# 842th iter done
# 843th iter done
# 844th iter done
# 845th iter done
# 846th iter done
# 847th iter done
# 848th iter done
# 849th iter done
# 850th iter done
# 851th iter done
# 852th iter done
# 853th iter done
# 854th iter done
# 855th iter done
# 856th iter done
# 857th iter done
# 858th iter done
# 859th iter done
# 860th iter done
# 861th iter done
# 862th iter done
# 863th iter done
# 864th iter done
# 865th iter done
# 866th iter done
# 867th iter done
# 868th iter done
# 869th iter done
# 870th iter done
# 871th iter done
# 872th iter done
# 873th iter done
# 874th iter done
# 875th iter done
# 876th iter done
# 877th iter done
# 878th iter done
# 879th iter done
# 880th iter done
# 881th iter done
# 882th iter done
# 883th iter done
# 884th iter done
# 885th iter done
# 886th iter done
# 887th iter done
# 888th iter done
# 889th iter done
# 890th iter done
# 891th iter done
# 892th iter done
# 893th iter done
# 894th iter done
# 895th iter done
# 896th iter done
# 897th iter done
# 898th iter done
# 899th iter done
# 900th iter done
# 901th iter done
# 902th iter done
# 903th iter done
# 904th iter done
# 905th iter done
# 906th iter done
# 907th iter done
# 908th iter done
# 909th iter done
# 910th iter done
# 911th iter done
# 912th iter done
# 913th iter done
# 914th iter done
# 915th iter done
# 916th iter done
# 917th iter done
# 918th iter done
# 919th iter done
# 920th iter done
# 921th iter done
# 922th iter done
# 923th iter done
# 924th iter done
# 925th iter done
# 926th iter done
# 927th iter done
# 928th iter done
# 929th iter done
# 930th iter done
# 931th iter done
# 932th iter done
# 933th iter done
# 934th iter done
# 935th iter done
# 936th iter done
# 937th iter done
# 938th iter done
# 939th iter done
# 940th iter done
# 941th iter done
# 942th iter done
# 943th iter done
# 944th iter done
# 945th iter done
# 946th iter done
# 947th iter done
# 948th iter done
# 949th iter done
# 950th iter done
# 951th iter done
# 952th iter done
# 953th iter done
# 954th iter done
# 955th iter done
# 956th iter done
# 957th iter done
# 958th iter done
# 959th iter done
# 960th iter done
# 961th iter done
# 962th iter done
# 963th iter done
# 964th iter done
# 965th iter done
# 966th iter done
# 967th iter done
# 968th iter done
# 969th iter done
# 970th iter done
# 971th iter done
# 972th iter done
# 973th iter done
# 974th iter done
# 975th iter done
# 976th iter done
# 977th iter done
# 978th iter done
# 979th iter done
# 980th iter done
# 981th iter done
# 982th iter done
# 983th iter done
# 984th iter done
# 985th iter done
# 986th iter done
# 987th iter done
# 988th iter done
# 989th iter done
# 990th iter done
# 991th iter done
# 992th iter done
# 993th iter done
# 994th iter done
# 995th iter done
# 996th iter done
# 997th iter done
# 998th iter done
# 999th iter done
# 1000th iter done
# 1001th iter done
# 1002th iter done
# 1003th iter done
# 1004th iter done
# 1005th iter done
# 1006th iter done
# 1007th iter done
# 1008th iter done
# 1009th iter done
# 1010th iter done
# 1011th iter done
# 1012th iter done
# 1013th iter done
# 1014th iter done
# 1015th iter done
# 1016th iter done
# 1017th iter done
# 1018th iter done
# 1019th iter done
# 1020th iter done
# 1021th iter done
# 1022th iter done
# 1023th iter done
# 1024th iter done
# 1025th iter done
# 1026th iter done
# 1027th iter done
# 1028th iter done
# 1029th iter done
# 1030th iter done
# 1031th iter done
# 1032th iter done
# 1033th iter done
# 1034th iter done
# 1035th iter done
# 1036th iter done
# 1037th iter done
# 1038th iter done
# 1039th iter done
# 1040th iter done
# 1041th iter done
# 1042th iter done
# 1043th iter done
# 1044th iter done
# 1045th iter done
# 1046th iter done
# 1047th iter done
# 1048th iter done
# 1049th iter done
# 1050th iter done
# 1051th iter done
# 1052th iter done
# 1053th iter done
# 1054th iter done
# 1055th iter done
# 1056th iter done
# 1057th iter done
# 1058th iter done
# 1059th iter done
# 1060th iter done
# 1061th iter done
# 1062th iter done
# 1063th iter done
# 1064th iter done
# 1065th iter done
# 1066th iter done
# 1067th iter done
# 1068th iter done
# 1069th iter done
# 1070th iter done
# 1071th iter done
# 1072th iter done
# 1073th iter done
# 1074th iter done
# 1075th iter done
# 1076th iter done
# 1077th iter done
# 1078th iter done
# 1079th iter done
# 1080th iter done
# 1081th iter done
# 1082th iter done
# 1083th iter done
# 1084th iter done
# 1085th iter done
# 1086th iter done
# 1087th iter done
# 1088th iter done
# 1089th iter done
# 1090th iter done
# 1091th iter done
# 1092th iter done
# 1093th iter done
# 1094th iter done
# 1095th iter done
# 1096th iter done
# 1097th iter done
# 1098th iter done
# 1099th iter done
# 1100th iter done
# 1101th iter done
# 1102th iter done
# 1103th iter done
# 1104th iter done
# 1105th iter done
# 1106th iter done
# 1107th iter done
# 1108th iter done
# 1109th iter done
# 1110th iter done
# 1111th iter done
# 1112th iter done
# 1113th iter done
# 1114th iter done
# 1115th iter done
# 1116th iter done
# 1117th iter done
# 1118th iter done
# 1119th iter done
# 1120th iter done
# 1121th iter done
# 1122th iter done
# 1123th iter done
# 1124th iter done
# 1125th iter done
# 1126th iter done
# 1127th iter done
# 1128th iter done
# 1129th iter done
# 1130th iter done
# 1131th iter done
# 1132th iter done
# 1133th iter done
# 1134th iter done
# 1135th iter done
# 1136th iter done
# 1137th iter done
# 1138th iter done
# 1139th iter done
# 1140th iter done
# 1141th iter done
# 1142th iter done
# 1143th iter done
# 1144th iter done
# 1145th iter done
# 1146th iter done
# 1147th iter done
# 1148th iter done
# 1149th iter done
# 1150th iter done
# 1151th iter done
# 1152th iter done
# 1153th iter done
# 1154th iter done
# 1155th iter done
# 1156th iter done
# 1157th iter done
# 1158th iter done
# 1159th iter done
# 1160th iter done
# 1161th iter done
# 1162th iter done
# 1163th iter done
# 1164th iter done
# 1165th iter done
# 1166th iter done
# 1167th iter done
# 1168th iter done
# 1169th iter done
# 1170th iter done
# 1171th iter done
# 1172th iter done
# 1173th iter done
# 1174th iter done
# 1175th iter done
# 1176th iter done
# 1177th iter done
# 1178th iter done
# 1179th iter done
# 1180th iter done
# 1181th iter done
# 1182th iter done
# 1183th iter done
# 1184th iter done
# 1185th iter done
# 1186th iter done
# 1187th iter done
# 1188th iter done
# 1189th iter done
# 1190th iter done
# 1191th iter done
# 1192th iter done
# 1193th iter done
# 1194th iter done
# 1195th iter done
# 1196th iter done
# 1197th iter done
# 1198th iter done
# 1199th iter done
# 1200th iter done
# 1201th iter done
# 1202th iter done
# 1203th iter done
# 1204th iter done
# 1205th iter done
# 1206th iter done
# 1207th iter done
# 1208th iter done
# 1209th iter done
# 1210th iter done
# 1211th iter done
# 1212th iter done
# 1213th iter done
# 1214th iter done
# 1215th iter done
# 1216th iter done
# 1217th iter done
# 1218th iter done
# 1219th iter done
# 1220th iter done
# 1221th iter done
# 1222th iter done
# 1223th iter done
# 1224th iter done
# 1225th iter done
# 1226th iter done
# 1227th iter done
# 1228th iter done
# 1229th iter done
# 1230th iter done
# 1231th iter done
# 1232th iter done
# 1233th iter done
# 1234th iter done
# 1235th iter done
# 1236th iter done
# 1237th iter done
# 1238th iter done
# 1239th iter done
# 1240th iter done
# 1241th iter done
# 1242th iter done
# 1243th iter done
# 1244th iter done
# 1245th iter done
# 1246th iter done
# 1247th iter done
# 1248th iter done
# 1249th iter done
# 1250th iter done
# 1251th iter done
# 1252th iter done
# 1253th iter done
# 1254th iter done
# 1255th iter done
# 1256th iter done
# 1257th iter done
# 1258th iter done
# 1259th iter done
# 1260th iter done
# 1261th iter done
# 1262th iter done
# 1263th iter done
# 1264th iter done
# 1265th iter done
# 1266th iter done
# 1267th iter done
# 1268th iter done
# 1269th iter done
# 1270th iter done
# 1271th iter done
# 1272th iter done
# 1273th iter done
# 1274th iter done
# 1275th iter done
# 1276th iter done
# 1277th iter done
# 1278th iter done
# 1279th iter done
# 1280th iter done
# 1281th iter done
# 1282th iter done
# 1283th iter done
# 1284th iter done
# 1285th iter done
# 1286th iter done
# 1287th iter done
# 1288th iter done
# 1289th iter done
# 1290th iter done
# 1291th iter done
# 1292th iter done
# 1293th iter done
# 1294th iter done
# 1295th iter done
# 1296th iter done
# 1297th iter done
# 1298th iter done
# 1299th iter done
# 1300th iter done
# 1301th iter done
# 1302th iter done
# 1303th iter done
# 1304th iter done
# 1305th iter done
# 1306th iter done
# 1307th iter done
# 1308th iter done
# 1309th iter done
# 1310th iter done
# 1311th iter done
# 1312th iter done
# 1313th iter done
# 1314th iter done
# 1315th iter done
# 1316th iter done
# 1317th iter done
# 1318th iter done
# 1319th iter done
# 1320th iter done
# 1321th iter done
# 1322th iter done
# 1323th iter done
# 1324th iter done
# 1325th iter done
# 1326th iter done
# 1327th iter done
# 1328th iter done
# 1329th iter done
# 1330th iter done
# 1331th iter done
# 1332th iter done
# 1333th iter done
# 1334th iter done
# 1335th iter done
# 1336th iter done
# 1337th iter done
# 1338th iter done
# 1339th iter done
# 1340th iter done
# 1341th iter done
# 1342th iter done
# 1343th iter done
# 1344th iter done
# 1345th iter done
# 1346th iter done
# 1347th iter done
# 1348th iter done
# 1349th iter done
# 1350th iter done
# 1351th iter done
# 1352th iter done
# 1353th iter done
# 1354th iter done
# 1355th iter done
# 1356th iter done
# 1357th iter done
# 1358th iter done
# 1359th iter done
# 1360th iter done
# 1361th iter done
# 1362th iter done
# 1363th iter done
# 1364th iter done
# 1365th iter done
# 1366th iter done
# 1367th iter done
# 1368th iter done
# 1369th iter done
# 1370th iter done
# 1371th iter done
# 1372th iter done
# 1373th iter done
# 1374th iter done
# 1375th iter done
# 1376th iter done
# 1377th iter done
# 1378th iter done
# 1379th iter done
# 1380th iter done
# 1381th iter done
# 1382th iter done
# 1383th iter done
# 1384th iter done
# 1385th iter done
# 1386th iter done
# 1387th iter done
# 1388th iter done
# 1389th iter done
# 1390th iter done
# 1391th iter done
# 1392th iter done
# 1393th iter done
# 1394th iter done
# 1395th iter done
# 1396th iter done
# 1397th iter done
# 1398th iter done
# 1399th iter done
# 1400th iter done
# 1401th iter done
# 1402th iter done
# 1403th iter done
# 1404th iter done
# 1405th iter done
# 1406th iter done
# 1407th iter done
# 1408th iter done
# 1409th iter done
# 1410th iter done
# 1411th iter done
# 1412th iter done
# 1413th iter done
# 1414th iter done
# 1415th iter done
# 1416th iter done
# 1417th iter done
# 1418th iter done
# 1419th iter done
# 1420th iter done
# 1421th iter done
# 1422th iter done
# 1423th iter done
# 1424th iter done
# 1425th iter done
# 1426th iter done
# 1427th iter done
# 1428th iter done
# 1429th iter done
# 1430th iter done
# 1431th iter done
# 1432th iter done
# 1433th iter done
# 1434th iter done
# 1435th iter done
# 1436th iter done
# 1437th iter done
# 1438th iter done
# 1439th iter done
# 1440th iter done
# 1441th iter done
# 1442th iter done
# 1443th iter done
# 1444th iter done
# 1445th iter done
# 1446th iter done
# 1447th iter done
# 1448th iter done
# 1449th iter done
# 1450th iter done
# 1451th iter done
# 1452th iter done
# 1453th iter done
# 1454th iter done
# 1455th iter done
# 1456th iter done
# 1457th iter done
# 1458th iter done
# 1459th iter done
# 1460th iter done
# 1461th iter done
# 1462th iter done
# 1463th iter done
# 1464th iter done
# 1465th iter done
# 1466th iter done
# 1467th iter done
# 1468th iter done
# 1469th iter done
# 1470th iter done
# 1471th iter done
# 1472th iter done
# 1473th iter done
# 1474th iter done
# 1475th iter done
# 1476th iter done
# 1477th iter done
# 1478th iter done
# 1479th iter done
# 1480th iter done
# 1481th iter done
# 1482th iter done
# 1483th iter done
# 1484th iter done
# 1485th iter done
# 1486th iter done
# 1487th iter done
# 1488th iter done
# 1489th iter done
# 1490th iter done
# 1491th iter done
# 1492th iter done
# 1493th iter done
# 1494th iter done
# 1495th iter done
# 1496th iter done
# 1497th iter done
# 1498th iter done
# 1499th iter done
# 1500th iter done
# 1501th iter done
# 1502th iter done
# 1503th iter done
# 1504th iter done
# 1505th iter done
# 1506th iter done
# 1507th iter done
# 1508th iter done
# 1509th iter done
# 1510th iter done
# 1511th iter done
# 1512th iter done
# 1513th iter done
# 1514th iter done
# 1515th iter done
# 1516th iter done
# 1517th iter done
# 1518th iter done
# 1519th iter done
# 1520th iter done
# 1521th iter done
# 1522th iter done
# 1523th iter done
# 1524th iter done
# 1525th iter done
# 1526th iter done
# 1527th iter done
# 1528th iter done
# 1529th iter done
# 1530th iter done
# 1531th iter done
# 1532th iter done
# 1533th iter done
# 1534th iter done
# 1535th iter done
# 1536th iter done
# 1537th iter done
# 1538th iter done
# 1539th iter done
# 1540th iter done
# 1541th iter done
# 1542th iter done
# 1543th iter done
# 1544th iter done
# 1545th iter done
# 1546th iter done
# 1547th iter done
# 1548th iter done
# 1549th iter done
# 1550th iter done
# 1551th iter done
# 1552th iter done
# 1553th iter done
# 1554th iter done
# 1555th iter done
# 1556th iter done
# 1557th iter done
# 1558th iter done
# 1559th iter done
# 1560th iter done
# 1561th iter done
# 1562th iter done
# 1563th iter done
# 1564th iter done
# 1565th iter done
# 1566th iter done
# 1567th iter done
# 1568th iter done
# 1569th iter done
# 1570th iter done
# 1571th iter done
# 1572th iter done
# 1573th iter done
# 1574th iter done
# 1575th iter done
# 1576th iter done
# 1577th iter done
# 1578th iter done
# 1579th iter done
# 1580th iter done
# 1581th iter done
# 1582th iter done
# 1583th iter done
# 1584th iter done
# 1585th iter done
# 1586th iter done
# 1587th iter done
# 1588th iter done
# 1589th iter done
# 1590th iter done
# 1591th iter done
# 1592th iter done
# 1593th iter done
# 1594th iter done
# 1595th iter done
# 1596th iter done
# 1597th iter done
# 1598th iter done
# 1599th iter done
# 1600th iter done
# 1601th iter done
# 1602th iter done
# 1603th iter done
# 1604th iter done
# 1605th iter done
# 1606th iter done
# 1607th iter done
# 1608th iter done
# 1609th iter done
# 1610th iter done
# 1611th iter done
# 1612th iter done
# 1613th iter done
# 1614th iter done
# 1615th iter done
# 1616th iter done
# 1617th iter done
# 1618th iter done
# 1619th iter done
# 1620th iter done
# 1621th iter done
# 1622th iter done
# 1623th iter done
# 1624th iter done
# 1625th iter done
# 1626th iter done
# 1627th iter done
# 1628th iter done
# 1629th iter done
# 1630th iter done
# 1631th iter done
# 1632th iter done
# 1633th iter done
# 1634th iter done
# 1635th iter done
# 1636th iter done
# 1637th iter done
# 1638th iter done
# 1639th iter done
# 1640th iter done
# 1641th iter done
# 1642th iter done
# 1643th iter done
# 1644th iter done
# 1645th iter done
# 1646th iter done
# 1647th iter done
# 1648th iter done
# 1649th iter done
# 1650th iter done
# 1651th iter done
# 1652th iter done
# 1653th iter done
# 1654th iter done
# 1655th iter done
# 1656th iter done
# 1657th iter done
# 1658th iter done
# 1659th iter done
# 1660th iter done
# 1661th iter done
# 1662th iter done
# 1663th iter done
# 1664th iter done
# 1665th iter done
# 1666th iter done
# 1667th iter done
# 1668th iter done
# 1669th iter done
# 1670th iter done
# 1671th iter done
# 1672th iter done
# 1673th iter done
# 1674th iter done
# 1675th iter done
# 1676th iter done
# 1677th iter done
# 1678th iter done
# 1679th iter done
# 1680th iter done
# 1681th iter done
# 1682th iter done
# 1683th iter done
# 1684th iter done
# 1685th iter done
# 1686th iter done
# 1687th iter done
# 1688th iter done
# 1689th iter done
# 1690th iter done
# 1691th iter done
# 1692th iter done
# 1693th iter done
# 1694th iter done
# 1695th iter done
# 1696th iter done
# 1697th iter done
# 1698th iter done
# 1699th iter done
# 1700th iter done
# 1701th iter done
# 1702th iter done
# 1703th iter done
# 1704th iter done
# 1705th iter done
# 1706th iter done
# 1707th iter done
# 1708th iter done
# 1709th iter done
# 1710th iter done
# 1711th iter done
# 1712th iter done
# 1713th iter done
# 1714th iter done
# 1715th iter done
# 1716th iter done
# 1717th iter done
# 1718th iter done
# 1719th iter done
# 1720th iter done
# 1721th iter done
# 1722th iter done
# 1723th iter done
# 1724th iter done
# 1725th iter done
# 1726th iter done
# 1727th iter done
# 1728th iter done
# 1729th iter done
# 1730th iter done
# 1731th iter done
# 1732th iter done
# 1733th iter done
# 1734th iter done
# 1735th iter done
# 1736th iter done
# 1737th iter done
# 1738th iter done
# 1739th iter done
# 1740th iter done
# 1741th iter done
# 1742th iter done
# 1743th iter done
# 1744th iter done
# 1745th iter done
# 1746th iter done
# 1747th iter done
# 1748th iter done
# 1749th iter done
# 1750th iter done
# 1751th iter done
# 1752th iter done
# 1753th iter done
# 1754th iter done
# 1755th iter done
# 1756th iter done
# 1757th iter done
# 1758th iter done
# 1759th iter done
# 1760th iter done
# 1761th iter done
# 1762th iter done
# 1763th iter done
# 1764th iter done
# 1765th iter done
# 1766th iter done
# 1767th iter done
# 1768th iter done
# 1769th iter done
# 1770th iter done
# 1771th iter done
# 1772th iter done
# 1773th iter done
# 1774th iter done
# 1775th iter done
# 1776th iter done
# 1777th iter done
# 1778th iter done
# 1779th iter done
# 1780th iter done
# 1781th iter done
# 1782th iter done
# 1783th iter done
# 1784th iter done
# 1785th iter done
# 1786th iter done
# 1787th iter done
# 1788th iter done
# 1789th iter done
# 1790th iter done
# 1791th iter done
# 1792th iter done
# 1793th iter done
# 1794th iter done
# 1795th iter done
# 1796th iter done
# 1797th iter done
# 1798th iter done
# 1799th iter done
# 1800th iter done
# 1801th iter done
# 1802th iter done
# 1803th iter done
# 1804th iter done
# 1805th iter done
# 1806th iter done
# 1807th iter done
# 1808th iter done
# 1809th iter done
# 1810th iter done
# 1811th iter done
# 1812th iter done
# 1813th iter done
# 1814th iter done
# 1815th iter done
# 1816th iter done
# 1817th iter done
# 1818th iter done
# 1819th iter done
# 1820th iter done
# 1821th iter done
# 1822th iter done
# 1823th iter done
# 1824th iter done
# 1825th iter done
# 1826th iter done
# 1827th iter done
# 1828th iter done
# 1829th iter done
# 1830th iter done
# 1831th iter done
# 1832th iter done
# 1833th iter done
# 1834th iter done
# 1835th iter done
# 1836th iter done
# 1837th iter done
# 1838th iter done
# 1839th iter done
# 1840th iter done
# 1841th iter done
# 1842th iter done
# 1843th iter done
# 1844th iter done
# 1845th iter done
# 1846th iter done
# 1847th iter done
# 1848th iter done
# 1849th iter done
# 1850th iter done
# 1851th iter done
# 1852th iter done
# 1853th iter done
# 1854th iter done
# 1855th iter done
# 1856th iter done
# 1857th iter done
# 1858th iter done
# 1859th iter done
# 1860th iter done
# 1861th iter done
# 1862th iter done
# 1863th iter done
# 1864th iter done
# 1865th iter done
# 1866th iter done
# 1867th iter done
# 1868th iter done
# 1869th iter done
# 1870th iter done
# 1871th iter done
# 1872th iter done
# 1873th iter done
# 1874th iter done
# 1875th iter done
# 1876th iter done
# 1877th iter done
# 1878th iter done
# 1879th iter done
# 1880th iter done
# 1881th iter done
# 1882th iter done
# 1883th iter done
# 1884th iter done
# 1885th iter done
# 1886th iter done
# 1887th iter done
# 1888th iter done
# 1889th iter done
# 1890th iter done
# 1891th iter done
# 1892th iter done
# 1893th iter done
# 1894th iter done
# 1895th iter done
# 1896th iter done
# 1897th iter done
# 1898th iter done
# 1899th iter done
# 1900th iter done
# 1901th iter done
# 1902th iter done
# 1903th iter done
# 1904th iter done
# 1905th iter done
# 1906th iter done
# 1907th iter done
# 1908th iter done
# 1909th iter done
# 1910th iter done
# 1911th iter done
# 1912th iter done
# 1913th iter done
# 1914th iter done
# 1915th iter done
# 1916th iter done
# 1917th iter done
# 1918th iter done
# 1919th iter done
# 1920th iter done
# 1921th iter done
# 1922th iter done
# 1923th iter done
# 1924th iter done
# 1925th iter done
# 1926th iter done
# 1927th iter done
# 1928th iter done
# 1929th iter done
# 1930th iter done
# 1931th iter done
# 1932th iter done
# 1933th iter done
# 1934th iter done
# 1935th iter done
# 1936th iter done
# 1937th iter done
# 1938th iter done
# 1939th iter done
# 1940th iter done
# 1941th iter done
# 1942th iter done
# 1943th iter done
# 1944th iter done
# 1945th iter done
# 1946th iter done
# 1947th iter done
# 1948th iter done
# 1949th iter done
# 1950th iter done
# 1951th iter done
# 1952th iter done
# 1953th iter done
# 1954th iter done
# 1955th iter done
# 1956th iter done
# 1957th iter done
# 1958th iter done
# 1959th iter done
# 1960th iter done
# 1961th iter done
# 1962th iter done
# 1963th iter done
# 1964th iter done
# 1965th iter done
# 1966th iter done
# 1967th iter done
# 1968th iter done
# 1969th iter done
# 1970th iter done
# 1971th iter done
# 1972th iter done
# 1973th iter done
# 1974th iter done
# 1975th iter done
# 1976th iter done
# 1977th iter done
# 1978th iter done
# 1979th iter done
# 1980th iter done
# 1981th iter done
# 1982th iter done
# 1983th iter done
# 1984th iter done
# 1985th iter done
# 1986th iter done
# 1987th iter done
# 1988th iter done
# 1989th iter done
# 1990th iter done
# 1991th iter done
# 1992th iter done
# 1993th iter done
# 1994th iter done
# 1995th iter done
# 1996th iter done
# 1997th iter done
# 1998th iter done
# 1999th iter done
# 2000th iter done
# 2001th iter done
# 2002th iter done
# 2003th iter done
# 2004th iter done
# 2005th iter done
# 2006th iter done
# 2007th iter done
# 2008th iter done
# 2009th iter done
# 2010th iter done
# 2011th iter done
# 2012th iter done
# 2013th iter done
# 2014th iter done
# 2015th iter done
# 2016th iter done
# 2017th iter done
# 2018th iter done
# 2019th iter done
# 2020th iter done
# 2021th iter done
# 2022th iter done
# 2023th iter done
# 2024th iter done
# 2025th iter done
# 2026th iter done
# 2027th iter done
# 2028th iter done
# 2029th iter done
# 2030th iter done
# 2031th iter done
# 2032th iter done
# 2033th iter done
# 2034th iter done
# 2035th iter done
# 2036th iter done
# 2037th iter done
# 2038th iter done
# 2039th iter done
# 2040th iter done
# 2041th iter done
# 2042th iter done
# 2043th iter done
# 2044th iter done
# 2045th iter done
# 2046th iter done
# 2047th iter done
# 2048th iter done
# 2049th iter done
# 2050th iter done
# 2051th iter done
# 2052th iter done
# 2053th iter done
# 2054th iter done
# 2055th iter done
# 2056th iter done
# 2057th iter done
# 2058th iter done
# 2059th iter done
# 2060th iter done
# 2061th iter done
# 2062th iter done
# 2063th iter done
# 2064th iter done
# 2065th iter done
# 2066th iter done
# 2067th iter done
# 2068th iter done
# 2069th iter done
# 2070th iter done
# 2071th iter done
# 2072th iter done
# 2073th iter done
# 2074th iter done
# 2075th iter done
# 2076th iter done
# 2077th iter done
# 2078th iter done
# 2079th iter done
# 2080th iter done
# 2081th iter done
# 2082th iter done
# 2083th iter done
# 2084th iter done
# 2085th iter done
# 2086th iter done
# 2087th iter done
# 2088th iter done
# 2089th iter done
# 2090th iter done
# 2091th iter done
# 2092th iter done
# 2093th iter done
# 2094th iter done
# 2095th iter done
# 2096th iter done
# 2097th iter done
# 2098th iter done
# 2099th iter done
# 2100th iter done
# 2101th iter done
# 2102th iter done
# 2103th iter done
# 2104th iter done
# 2105th iter done
# 2106th iter done
# 2107th iter done
# 2108th iter done
# 2109th iter done
# 2110th iter done
# 2111th iter done
# 2112th iter done
# 2113th iter done
# 2114th iter done
# 2115th iter done
# 2116th iter done
# 2117th iter done
# 2118th iter done
# 2119th iter done
# 2120th iter done
# 2121th iter done
# 2122th iter done
# 2123th iter done
# 2124th iter done
# 2125th iter done
# 2126th iter done
# 2127th iter done
# 2128th iter done
# 2129th iter done
# 2130th iter done
# 2131th iter done
# 2132th iter done
# 2133th iter done
# 2134th iter done
# 2135th iter done
# 2136th iter done
# 2137th iter done
# 2138th iter done
# 2139th iter done
# 2140th iter done
# 2141th iter done
# 2142th iter done
# 2143th iter done
# 2144th iter done
# 2145th iter done
# 2146th iter done
# 2147th iter done
# 2148th iter done
# 2149th iter done
# 2150th iter done
# 2151th iter done
# 2152th iter done
# 2153th iter done
# 2154th iter done
# 2155th iter done
# 2156th iter done
# 2157th iter done
# 2158th iter done
# 2159th iter done
# 2160th iter done
# 2161th iter done
# 2162th iter done
# 2163th iter done
# 2164th iter done
# 2165th iter done
# 2166th iter done
# 2167th iter done
# 2168th iter done
# 2169th iter done
# 2170th iter done
# 2171th iter done
# 2172th iter done
# 2173th iter done
# 2174th iter done
# 2175th iter done
# 2176th iter done
# 2177th iter done
# 2178th iter done
# 2179th iter done
# 2180th iter done
# 2181th iter done
# 2182th iter done
# 2183th iter done
# 2184th iter done
# 2185th iter done
# 2186th iter done
# 2187th iter done
# 2188th iter done
# 2189th iter done
# 2190th iter done
# 2191th iter done
# 2192th iter done
# 2193th iter done
# 2194th iter done
# 2195th iter done
# 2196th iter done
# 2197th iter done
# 2198th iter done
# 2199th iter done
# 2200th iter done
# tensor(0.2555)

# %%
result_df = raw_df[['ud','ma','volume']].copy()
pred = pd.DataFrame(pred_list[:,-1,:], columns=['ud','ma','volume']) * (result_df.max(axis=0)-result_df.min(axis=0)) + result_df.min(axis=0)
orig = pd.DataFrame(orig_list[:,-1,:], columns=['ud','ma','volume']) * (result_df.max(axis=0)-result_df.min(axis=0)) + result_df.min(axis=0)

print(pred)
print(orig)
# Out:
#              ud          ma    volume
# 0     -2.184845   -7.343445  3.244495
# 1     31.056152   15.320679  2.050536
# 2     50.184326   65.647644  2.418587
# 3     33.258682   99.633026  2.227174
# 4     10.134796   94.862488  2.716860
# ...         ...         ...       ...
# 2196  99.784927   23.788025  2.210980
# 2197  57.828079  300.000000  2.207002
# 2198  61.330368   58.672852  3.850240
# 2199  66.190018   90.189453  2.184935
# 2200  70.684891   81.120026  3.537884
#
# [2201 rows x 3 columns]
#              ud         ma    volume
# 0     -0.029999  59.796509  1.335180
# 1     -4.809998 -27.092010  3.636848
# 2     55.830002 -22.984985  3.948858
# 3      0.410004 -10.763000  2.507813
# 4    -34.500000  -6.591003  2.464006
# ...         ...        ...       ...
# 2196  -4.070007 -36.807007  3.106523
# 2197 -17.009995 -90.885010  1.484441
# 2198 -19.979996  -4.312500  2.381502
# 2199  16.110016 -32.662994  2.336036
# 2200  17.580002  68.588013  2.891140
#
# [2201 rows x 3 columns]

# %%
# We can see that predicted values are much right-skewed compared to the original values

print(len(orig[orig['ud']>0]))
print(len(orig[orig['ud']<0]))
print(len(pred[pred['ud']>0]))
print(len(pred[pred['ud']<0]))
# Out:
# 1087
# 1112
# 2090
# 111

# %%
orig_big = orig[orig['ud'] > 0]
big_correct = 0
for i in orig_big.index:
  if pred.loc[i,'ud'] > 0:
    big_correct += 1
big_correct_rate = big_correct / len(orig_big.index)
print(big_correct_rate)
# Out:
# 0.3581395348837209

# %%
pred_big = pred[pred['ud'] > 40]
big_correct = 0
for i in pred_big.index:
  if orig.loc[i,'ud'] > -40:
    big_correct += 1
big_correct_rate = big_correct / len(pred_big.index)
print(big_correct_rate)
# Out:
# 0.7142857142857143

# %%
small = orig[orig['ud'] < 0]
small_correct = 0
for i in small.index:
  if pred.loc[i,'ud'] < 0:
    small_correct += 1
small_correct_rate = small_correct / len(small.index)
print(small_correct_rate)
# Out:
# 0.647636039250669

# %%
pred_small = pred[pred['ud'] < -40]
small_correct = 0
for i in pred_small.index:
  if orig.loc[i,'ud'] < 40:
    small_correct += 1
small_correct_rate = small_correct / len(pred_small.index)
print(small_correct_rate)
# Out:
# 0.9150943396226415

# %% [markdown]
# # GAN Model 2 (Convolutional Layers)

# %%
image_width2 = 20    # Time horizon for each image (20 minutes)
image_depth2 = 3     # View each feature as each channel

# Obtain dataset by applying sliding window of size 20 to data_list 
data_set2 = torch.zeros((data_list.size()[0] - image_width2 + 1, image_width2, data_list.size()[1]))
for i in range(data_list.size()[0] - image_width2 + 1):
  data_set2[i,:,:] = data_list[i:i+image_width2,:]
data_set2 = torch.transpose(data_set2, 1, 2)
print(data_set2.size())
# Out:
# torch.Size([44001, 4, 20])

# %%
# Second and third dimension are transposed compared to the case of the Linear-layer-only model
# this is because nn.Linear views the third dimension as the channnels
# while nn.Conv1d view the second dimension as the channels

image_set2 = data_set2[:,:3,:]                     # Input features
latent_set2 = torch.unsqueeze(data_set2[:,3,:],1)  # Target feature

print(image_set2.size())
print(latent_set2.size())
# Out:
# torch.Size([44001, 3, 20])
# torch.Size([44001, 1, 20])

# %%
# Choose training and validation data randomly (80% for training, 10% for validation, 10% for testing)
rand_idx = np.random.choice(data_set2.size()[0],size=data_set2.size()[0], replace=False)
train_idx = rand_idx[:(data_set2.size()[0]//10)*8]
val_idx = rand_idx[(data_set2.size()[0]//10)*8:(data_set2.size()[0]//10)*9]
test_idx = rand_idx[(data_set2.size()[0]//10)*9:]

train_image2 = image_set2[train_idx,:,:]   # Train input features
train_latent2 = latent_set2[train_idx,:]   # Train target feature
val_image2 = image_set2[val_idx,:,:]       # Validation train features
val_latent2 = latent_set2[val_idx,:]       # Validation target feature
test_image2 = image_set2[test_idx,:,:]     # Test train features
test_latent2 = latent_set2[test_idx,:]     # Test target feature

print(train_image2.size())
print(train_latent2.size())
print(val_image2.size())
print(val_latent2.size())
print(test_image2.size())
print(test_latent2.size())
# Out:
# torch.Size([35200, 3, 20])
# torch.Size([35200, 1, 20])
# torch.Size([4400, 3, 20])
# torch.Size([4400, 1, 20])
# torch.Size([4401, 3, 20])
# torch.Size([4401, 1, 20])

# %%
# Put above training, validation, test data into Dataloader of Pytorch

train_set2 = TensorDataset(train_image2, train_latent2)
val_set2 = TensorDataset(val_image2, val_latent2)
test_set2 = TensorDataset(test_image2, test_latent2)

bs2 = 16
train_loader2 = torch.utils.data.DataLoader(dataset=train_set2, batch_size=bs2, shuffle=True)
val_loader2 = torch.utils.data.DataLoader(dataset=val_set2, batch_size=1, shuffle=False)
test_loader2 = torch.utils.data.DataLoader(dataset=test_set2, batch_size=1, shuffle=False)

# %%
class Generator(nn.Module):
    '''
    2 Conv1d layers, then 1 Squeeze-and-Excitation layer, then 2 Conv1d layers
    '''
    def __init__(self, latent_dim, image_dim):
        super(Generator, self).__init__()
        lat = latent_dim       
        self.layer1 = nn.Sequential(
            nn.Conv1d(lat, lat*2, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm1d(lat*2),
            nn.ReLU()
        )
        self.layer2 = nn.Sequential(
            nn.Conv1d(lat*2, lat*4, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm1d(lat*4),
            nn.ReLU()
        )
        self.globalAvgPool = nn.AdaptiveAvgPool1d(1)
        self.se = nn.Sequential(
            nn.Linear(lat*4, lat),
            nn.ReLU(),
            nn.Linear(lat, lat*4),
            nn.Sigmoid()
        )
        self.layer3 = nn.Sequential(
            nn.Conv1d(lat*4, lat*8, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm1d(lat*8),
            nn.ReLU()
        )
        self.layer4 = nn.Sequential(
            nn.Conv1d(lat*8, image_dim, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm1d(image_dim),
            nn.ReLU()
        )
    
    # forward method
    def forward(self, x): 
        out = self.layer1(x)
        out = self.layer2(out)
        avg_out = torch.squeeze(self.globalAvgPool(out))
        se_out = self.se(avg_out).view(out.size()[0], out.size()[1], 1)
        out = out * se_out.expand_as(out)
        out = self.layer3(out)
        out = self.layer4(out)
        return torch.sigmoid(out)
    
    
class Discriminator(nn.Module):
    '''
    2 Conv1d layers, then 1 Squeeze-and-Excitation layer, then 2 Conv1d layers
    '''
    def __init__(self, image_dim):
        super(Discriminator, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv1d(image_dim, image_dim*12, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm1d(image_dim*12),
            nn.ReLU()
        )
        self.layer2 = nn.Sequential(
            nn.Conv1d(image_dim*12, image_dim*8, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm1d(image_dim*8),
            nn.ReLU()
        )
        self.globalAvgPool = nn.AdaptiveAvgPool1d(1)
        self.se = nn.Sequential(
            nn.Linear(image_dim*8, image_dim*2),
            nn.ReLU(),
            nn.Linear(image_dim*2, image_dim*8),
            nn.Sigmoid()
        )
        self.layer3 = nn.Sequential(
            nn.Conv1d(image_dim*8, image_dim*4, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm1d(image_dim*4),
            nn.ReLU()
        )
        self.layer4 = nn.Sequential(
            nn.Conv1d(image_dim*4, 1, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm1d(1),
            nn.ReLU()
        )
    
    # forward method
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        avg_out = torch.squeeze(self.globalAvgPool(out))
        se_out = self.se(avg_out).view(out.size()[0], out.size()[1], 1)
        out = out * se_out.expand_as(out)
        out = self.layer3(out)
        out = self.layer4(out)
        return torch.sigmoid(out)
    

z_dim = 1

G = Generator(latent_dim = z_dim, image_dim = image_depth2).to(device)
D = Discriminator(image_dim = image_depth2).to(device)

G_optimizer = optim.Adam(G.parameters(), lr = 0.0000035)
D_optimizer = optim.Adam(D.parameters(), lr = 0.0000035)

# %%
# Training process

n_epoch = 100

# Alternate the optimization process (1 time after 1 time) of Discriminator and Generator
for epoch in range(n_epoch):           
    D_losses, G_losses = [], []
    for x, y in train_loader2:
        D.zero_grad()
        x_real = x.to(device)
        D_real_loss = torch.mean(torch.log(D(x_real)))
        Z = y.to(device)
        D_fake_loss = torch.mean(torch.log(1-D(G(Z))))
        D_loss = -(D_real_loss + D_fake_loss)
        D_loss.backward()
        D_optimizer.step()
        D_losses.append(D_loss.data.item())
        
        G.zero_grad()
        
        Z = y.to(device)
        G_loss = torch.mean(torch.log(1-D(G(Z))))
        G_loss.backward()
        G_optimizer.step()
        G_losses.append(G_loss.data.item())
    D_losses, G_losses = torch.tensor(D_losses), torch.tensor(G_losses)    
    print('[%d/%d]: loss_d: %.3f, loss_g: %.3f' % (epoch, n_epoch, torch.mean(D_losses), torch.mean(G_losses)))
# Out:
# [0/100]: loss_d: 1.473, loss_g: -0.913
# [1/100]: loss_d: 1.438, loss_g: -0.881
# [2/100]: loss_d: 1.418, loss_g: -0.863
# [3/100]: loss_d: 1.407, loss_g: -0.852
# [4/100]: loss_d: 1.400, loss_g: -0.844
# [5/100]: loss_d: 1.394, loss_g: -0.835
# [6/100]: loss_d: 1.390, loss_g: -0.829
# [7/100]: loss_d: 1.388, loss_g: -0.825
# [8/100]: loss_d: 1.383, loss_g: -0.819
# [9/100]: loss_d: 1.377, loss_g: -0.812
# [10/100]: loss_d: 1.371, loss_g: -0.805
# [11/100]: loss_d: 1.366, loss_g: -0.799
# [12/100]: loss_d: 1.362, loss_g: -0.794
# [13/100]: loss_d: 1.360, loss_g: -0.791
# [14/100]: loss_d: 1.360, loss_g: -0.788
# [15/100]: loss_d: 1.359, loss_g: -0.786
# [16/100]: loss_d: 1.358, loss_g: -0.783
# [17/100]: loss_d: 1.357, loss_g: -0.779
# [18/100]: loss_d: 1.351, loss_g: -0.771
# [19/100]: loss_d: 1.343, loss_g: -0.761
# [20/100]: loss_d: 1.337, loss_g: -0.754
# [21/100]: loss_d: 1.334, loss_g: -0.750
# [22/100]: loss_d: 1.335, loss_g: -0.750
# [23/100]: loss_d: 1.332, loss_g: -0.746
# [24/100]: loss_d: 1.327, loss_g: -0.740
# [25/100]: loss_d: 1.321, loss_g: -0.734
# [26/100]: loss_d: 1.314, loss_g: -0.727
# [27/100]: loss_d: 1.307, loss_g: -0.722
# [28/100]: loss_d: 1.301, loss_g: -0.718
# [29/100]: loss_d: 1.296, loss_g: -0.714
# [30/100]: loss_d: 1.291, loss_g: -0.711
# [31/100]: loss_d: 1.287, loss_g: -0.709
# [32/100]: loss_d: 1.284, loss_g: -0.708
# [33/100]: loss_d: 1.282, loss_g: -0.707
# [34/100]: loss_d: 1.282, loss_g: -0.708
# [35/100]: loss_d: 1.281, loss_g: -0.708
# [36/100]: loss_d: 1.277, loss_g: -0.705
# [37/100]: loss_d: 1.271, loss_g: -0.703
# [38/100]: loss_d: 1.269, loss_g: -0.703
# [39/100]: loss_d: 1.270, loss_g: -0.704
# [40/100]: loss_d: 1.270, loss_g: -0.705
# [41/100]: loss_d: 1.269, loss_g: -0.705
# [42/100]: loss_d: 1.269, loss_g: -0.705
# [43/100]: loss_d: 1.269, loss_g: -0.705
# [44/100]: loss_d: 1.268, loss_g: -0.705
# [45/100]: loss_d: 1.268, loss_g: -0.705
# [46/100]: loss_d: 1.266, loss_g: -0.705
# [47/100]: loss_d: 1.265, loss_g: -0.704
# [48/100]: loss_d: 1.263, loss_g: -0.703
# [49/100]: loss_d: 1.261, loss_g: -0.703
# [50/100]: loss_d: 1.260, loss_g: -0.703
# [51/100]: loss_d: 1.259, loss_g: -0.702
# [52/100]: loss_d: 1.258, loss_g: -0.702
# [53/100]: loss_d: 1.257, loss_g: -0.702
# [54/100]: loss_d: 1.257, loss_g: -0.702
# [55/100]: loss_d: 1.256, loss_g: -0.702
# [56/100]: loss_d: 1.256, loss_g: -0.702
# [57/100]: loss_d: 1.256, loss_g: -0.703
# [58/100]: loss_d: 1.255, loss_g: -0.702
# [59/100]: loss_d: 1.253, loss_g: -0.701
# [60/100]: loss_d: 1.250, loss_g: -0.699
# [61/100]: loss_d: 1.250, loss_g: -0.700
# [62/100]: loss_d: 1.251, loss_g: -0.702
# [63/100]: loss_d: 1.251, loss_g: -0.702
# [64/100]: loss_d: 1.249, loss_g: -0.701
# [65/100]: loss_d: 1.247, loss_g: -0.700
# [66/100]: loss_d: 1.246, loss_g: -0.700
# [67/100]: loss_d: 1.245, loss_g: -0.700
# [68/100]: loss_d: 1.245, loss_g: -0.700
# [69/100]: loss_d: 1.244, loss_g: -0.700
# [70/100]: loss_d: 1.243, loss_g: -0.700
# [71/100]: loss_d: 1.242, loss_g: -0.700
# [72/100]: loss_d: 1.242, loss_g: -0.700
# [73/100]: loss_d: 1.241, loss_g: -0.701
# [74/100]: loss_d: 1.241, loss_g: -0.701
# [75/100]: loss_d: 1.240, loss_g: -0.701
# [76/100]: loss_d: 1.239, loss_g: -0.701
# [77/100]: loss_d: 1.238, loss_g: -0.700
# [78/100]: loss_d: 1.236, loss_g: -0.700
# [79/100]: loss_d: 1.234, loss_g: -0.699
# [80/100]: loss_d: 1.233, loss_g: -0.699
# [81/100]: loss_d: 1.231, loss_g: -0.698
# [82/100]: loss_d: 1.230, loss_g: -0.698
# [83/100]: loss_d: 1.228, loss_g: -0.698
# [84/100]: loss_d: 1.227, loss_g: -0.698
# [85/100]: loss_d: 1.226, loss_g: -0.698
# [86/100]: loss_d: 1.226, loss_g: -0.698
# [87/100]: loss_d: 1.225, loss_g: -0.698
# [88/100]: loss_d: 1.223, loss_g: -0.698
# [89/100]: loss_d: 1.222, loss_g: -0.698
# [90/100]: loss_d: 1.221, loss_g: -0.698
# [91/100]: loss_d: 1.220, loss_g: -0.698
# [92/100]: loss_d: 1.219, loss_g: -0.698
# [93/100]: loss_d: 1.218, loss_g: -0.698
# [94/100]: loss_d: 1.216, loss_g: -0.698
# [95/100]: loss_d: 1.215, loss_g: -0.698
# [96/100]: loss_d: 1.214, loss_g: -0.698
# [97/100]: loss_d: 1.213, loss_g: -0.698
# [98/100]: loss_d: 1.211, loss_g: -0.698
# [99/100]: loss_d: 1.210, loss_g: -0.698

# %%
# Save the weight values of the trained Generator and Discriminator

torch.save(G.state_dict(), '/content/generator.pt')
torch.save(D.state_dict(), '/content/discriminator.pt')

# %%
# Load the weight values of the trained Generator and Disciminator

G = Generator(latent_dim = z_dim, image_dim = image_depth2).to(device)
D = Discriminator(image_dim = image_depth2).to(device)
G.load_state_dict(torch.load('generator.pt',map_location=device))
D.load_state_dict(torch.load('discriminator.pt',map_location=device))
G.eval()
D.eval()
G.requires_grad_(False)
D.requires_grad_(False)
# Out:
# Discriminator(
#   (layer1): Sequential(
#     (0): Conv1d(3, 36, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#     (1): BatchNorm1d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (layer2): Sequential(
#     (0): Conv1d(36, 24, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#     (1): BatchNorm1d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (globalAvgPool): AdaptiveAvgPool1d(output_size=1)
#   (se): Sequential(
#     (0): Linear(in_features=24, out_features=6, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=6, out_features=24, bias=True)
#     (3): Sigmoid()
#   )
#   (layer3): Sequential(
#     (0): Conv1d(24, 12, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#     (1): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (layer4): Sequential(
#     (0): Conv1d(12, 1, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#     (1): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
# )

# %%
# Validation process
# This includes the masked prediction process

loss_list2 = []
pred_list2 = torch.zeros(len(val_loader2), 1, image_depth2, image_width2)
orig_list2 = torch.zeros(len(val_loader2), 1, image_depth2, image_width2)
disc_list2 = torch.zeros(len(val_loader2))

for iter, (images, latents) in enumerate(val_loader2):
  image_num = images.size()[0]
  original = images.clone()
  prediction = torch.zeros(image_num, image_depth2, image_width2)
  
  
  # Masking process for the last time index (last 1 minute) of the image
  # Masking is done by setting values equal to the median values of the whole data
  mask = torch.ones_like(images, dtype=torch.bool)
  mask[:,:,-1] = 0
  images[mask.logical_not()] = threshold*torch.ones_like(images[mask.logical_not()])
  X = images.clone().requires_grad_(True)
  
  
  objective_list = []
  for i in range(100):    
    Z = latents.to(device)
    objective = torch.mean(torch.log(D(X.to(device)))+torch.log(1-D(G(Z))))
    objective.backward()
    objective_list.append(objective)
    X_grad = X.grad.requires_grad_(False)
    X = X.requires_grad_(False)
    projection = torch.clamp(X.data[mask.logical_not()] 
                             - 0.001*X_grad[mask.logical_not()], min=0, max=1)
    X.data[mask.logical_not()] = projection
    X.requires_grad_(True)
  prediction = X
  pred_list2[iter,:,:,:] = prediction.requires_grad_(False)
  orig_list2[iter,:,:,:] = original
  disc_list2[iter] = torch.mean(D(X.to(device)))
  
  # Loss is computed for the last time index (masked index) only
  loss = torch.mean(torch.square(prediction[:,0,-1] - original[:,0,-1]))
  loss_list2.append(loss)
  
  print(str(iter)+'th iter completed')
loss_list2 = torch.tensor(loss_list2)
pred_list2 = torch.squeeze(pred_list2, 1).numpy()
orig_list2 = torch.squeeze(orig_list2, 1).numpy()
print(torch.sqrt(loss_list2.mean()))
# Out:
# 0th iter completed
# 1th iter completed
# 2th iter completed
# 3th iter completed
# 4th iter completed
# 5th iter completed
# 6th iter completed
# 7th iter completed
# 8th iter completed
# 9th iter completed
# 10th iter completed
# 11th iter completed
# 12th iter completed
# 13th iter completed
# 14th iter completed
# 15th iter completed
# 16th iter completed
# 17th iter completed
# 18th iter completed
# 19th iter completed
# 20th iter completed
# 21th iter completed
# 22th iter completed
# 23th iter completed
# 24th iter completed
# 25th iter completed
# 26th iter completed
# 27th iter completed
# 28th iter completed
# 29th iter completed
# 30th iter completed
# 31th iter completed
# 32th iter completed
# 33th iter completed
# 34th iter completed
# 35th iter completed
# 36th iter completed
# 37th iter completed
# 38th iter completed
# 39th iter completed
# 40th iter completed
# 41th iter completed
# 42th iter completed
# 43th iter completed
# 44th iter completed
# 45th iter completed
# 46th iter completed
# 47th iter completed
# 48th iter completed
# 49th iter completed
# 50th iter completed
# 51th iter completed
# 52th iter completed
# 53th iter completed
# 54th iter completed
# 55th iter completed
# 56th iter completed
# 57th iter completed
# 58th iter completed
# 59th iter completed
# 60th iter completed
# 61th iter completed
# 62th iter completed
# 63th iter completed
# 64th iter completed
# 65th iter completed
# 66th iter completed
# 67th iter completed
# 68th iter completed
# 69th iter completed
# 70th iter completed
# 71th iter completed
# 72th iter completed
# 73th iter completed
# 74th iter completed
# 75th iter completed
# 76th iter completed
# 77th iter completed
# 78th iter completed
# 79th iter completed
# 80th iter completed
# 81th iter completed
# 82th iter completed
# 83th iter completed
# 84th iter completed
# 85th iter completed
# 86th iter completed
# 87th iter completed
# 88th iter completed
# 89th iter completed
# 90th iter completed
# 91th iter completed
# 92th iter completed
# 93th iter completed
# 94th iter completed
# 95th iter completed
# 96th iter completed
# 97th iter completed
# 98th iter completed
# 99th iter completed
# 100th iter completed
# 101th iter completed
# 102th iter completed
# 103th iter completed
# 104th iter completed
# 105th iter completed
# 106th iter completed
# 107th iter completed
# 108th iter completed
# 109th iter completed
# 110th iter completed
# 111th iter completed
# 112th iter completed
# 113th iter completed
# 114th iter completed
# 115th iter completed
# 116th iter completed
# 117th iter completed
# 118th iter completed
# 119th iter completed
# 120th iter completed
# 121th iter completed
# 122th iter completed
# 123th iter completed
# 124th iter completed
# 125th iter completed
# 126th iter completed
# 127th iter completed
# 128th iter completed
# 129th iter completed
# 130th iter completed
# 131th iter completed
# 132th iter completed
# 133th iter completed
# 134th iter completed
# 135th iter completed
# 136th iter completed
# 137th iter completed
# 138th iter completed
# 139th iter completed
# 140th iter completed
# 141th iter completed
# 142th iter completed
# 143th iter completed
# 144th iter completed
# 145th iter completed
# 146th iter completed
# 147th iter completed
# 148th iter completed
# 149th iter completed
# 150th iter completed
# 151th iter completed
# 152th iter completed
# 153th iter completed
# 154th iter completed
# 155th iter completed
# 156th iter completed
# 157th iter completed
# 158th iter completed
# 159th iter completed
# 160th iter completed
# 161th iter completed
# 162th iter completed
# 163th iter completed
# 164th iter completed
# 165th iter completed
# 166th iter completed
# 167th iter completed
# 168th iter completed
# 169th iter completed
# 170th iter completed
# 171th iter completed
# 172th iter completed
# 173th iter completed
# 174th iter completed
# 175th iter completed
# 176th iter completed
# 177th iter completed
# 178th iter completed
# 179th iter completed
# 180th iter completed
# 181th iter completed
# 182th iter completed
# 183th iter completed
# 184th iter completed
# 185th iter completed
# 186th iter completed
# 187th iter completed
# 188th iter completed
# 189th iter completed
# 190th iter completed
# 191th iter completed
# 192th iter completed
# 193th iter completed
# 194th iter completed
# 195th iter completed
# 196th iter completed
# 197th iter completed
# 198th iter completed
# 199th iter completed
# 200th iter completed
# 201th iter completed
# 202th iter completed
# 203th iter completed
# 204th iter completed
# 205th iter completed
# 206th iter completed
# 207th iter completed
# 208th iter completed
# 209th iter completed
# 210th iter completed
# 211th iter completed
# 212th iter completed
# 213th iter completed
# 214th iter completed
# 215th iter completed
# 216th iter completed
# 217th iter completed
# 218th iter completed
# 219th iter completed
# 220th iter completed
# 221th iter completed
# 222th iter completed
# 223th iter completed
# 224th iter completed
# 225th iter completed
# 226th iter completed
# 227th iter completed
# 228th iter completed
# 229th iter completed
# 230th iter completed
# 231th iter completed
# 232th iter completed
# 233th iter completed
# 234th iter completed
# 235th iter completed
# 236th iter completed
# 237th iter completed
# 238th iter completed
# 239th iter completed
# 240th iter completed
# 241th iter completed
# 242th iter completed
# 243th iter completed
# 244th iter completed
# 245th iter completed
# 246th iter completed
# 247th iter completed
# 248th iter completed
# 249th iter completed
# 250th iter completed
# 251th iter completed
# 252th iter completed
# 253th iter completed
# 254th iter completed
# 255th iter completed
# 256th iter completed
# 257th iter completed
# 258th iter completed
# 259th iter completed
# 260th iter completed
# 261th iter completed
# 262th iter completed
# 263th iter completed
# 264th iter completed
# 265th iter completed
# 266th iter completed
# 267th iter completed
# 268th iter completed
# 269th iter completed
# 270th iter completed
# 271th iter completed
# 272th iter completed
# 273th iter completed
# 274th iter completed
# 275th iter completed
# 276th iter completed
# 277th iter completed
# 278th iter completed
# 279th iter completed
# 280th iter completed
# 281th iter completed
# 282th iter completed
# 283th iter completed
# 284th iter completed
# 285th iter completed
# 286th iter completed
# 287th iter completed
# 288th iter completed
# 289th iter completed
# 290th iter completed
# 291th iter completed
# 292th iter completed
# 293th iter completed
# 294th iter completed
# 295th iter completed
# 296th iter completed
# 297th iter completed
# 298th iter completed
# 299th iter completed
# 300th iter completed
# 301th iter completed
# 302th iter completed
# 303th iter completed
# 304th iter completed
# 305th iter completed
# 306th iter completed
# 307th iter completed
# 308th iter completed
# 309th iter completed
# 310th iter completed
# 311th iter completed
# 312th iter completed
# 313th iter completed
# 314th iter completed
# 315th iter completed
# 316th iter completed
# 317th iter completed
# 318th iter completed
# 319th iter completed
# 320th iter completed
# 321th iter completed
# 322th iter completed
# 323th iter completed
# 324th iter completed
# 325th iter completed
# 326th iter completed
# 327th iter completed
# 328th iter completed
# 329th iter completed
# 330th iter completed
# 331th iter completed
# 332th iter completed
# 333th iter completed
# 334th iter completed
# 335th iter completed
# 336th iter completed
# 337th iter completed
# 338th iter completed
# 339th iter completed
# 340th iter completed
# 341th iter completed
# 342th iter completed
# 343th iter completed
# 344th iter completed
# 345th iter completed
# 346th iter completed
# 347th iter completed
# 348th iter completed
# 349th iter completed
# 350th iter completed
# 351th iter completed
# 352th iter completed
# 353th iter completed
# 354th iter completed
# 355th iter completed
# 356th iter completed
# 357th iter completed
# 358th iter completed
# 359th iter completed
# 360th iter completed
# 361th iter completed
# 362th iter completed
# 363th iter completed
# 364th iter completed
# 365th iter completed
# 366th iter completed
# 367th iter completed
# 368th iter completed
# 369th iter completed
# 370th iter completed
# 371th iter completed
# 372th iter completed
# 373th iter completed
# 374th iter completed
# 375th iter completed
# 376th iter completed
# 377th iter completed
# 378th iter completed
# 379th iter completed
# 380th iter completed
# 381th iter completed
# 382th iter completed
# 383th iter completed
# 384th iter completed
# 385th iter completed
# 386th iter completed
# 387th iter completed
# 557th iter completed
# 558th iter completed
# 559th iter completed
# 560th iter completed
# 561th iter completed
# 562th iter completed
# 563th iter completed
# 564th iter completed
# 565th iter completed
# 566th iter completed
# 567th iter completed
# 568th iter completed
# 569th iter completed
# 570th iter completed
# 571th iter completed
# 572th iter completed
# 573th iter completed
# 574th iter completed
# 575th iter completed
# 576th iter completed
# 577th iter completed
# 578th iter completed
# 579th iter completed
# 580th iter completed
# 581th iter completed
# 582th iter completed
# 583th iter completed
# 584th iter completed
# 585th iter completed
# 586th iter completed
# 587th iter completed
# 588th iter completed
# 589th iter completed
# 590th iter completed
# 591th iter completed
# 592th iter completed
# 593th iter completed
# 594th iter completed
# 595th iter completed
# 596th iter completed
# 597th iter completed
# 598th iter completed
# 599th iter completed
# 600th iter completed
# 601th iter completed
# 602th iter completed
# 603th iter completed
# 604th iter completed
# 605th iter completed
# 606th iter completed
# 607th iter completed
# 608th iter completed
# 609th iter completed
# 610th iter completed
# 611th iter completed
# 612th iter completed
# 613th iter completed
# 614th iter completed
# 615th iter completed
# 616th iter completed
# 617th iter completed
# 618th iter completed
# 619th iter completed
# 620th iter completed
# 621th iter completed
# 622th iter completed
# 623th iter completed
# 624th iter completed
# 625th iter completed
# 626th iter completed
# 627th iter completed
# 628th iter completed
# 629th iter completed
# 630th iter completed
# 631th iter completed
# 632th iter completed
# 633th iter completed
# 634th iter completed
# 635th iter completed
# 636th iter completed
# 637th iter completed
# 638th iter completed
# 639th iter completed
# 640th iter completed
# 641th iter completed
# 642th iter completed
# 643th iter completed
# 644th iter completed
# 645th iter completed
# 646th iter completed
# 647th iter completed
# 648th iter completed
# 649th iter completed
# 650th iter completed
# 651th iter completed
# 652th iter completed
# 653th iter completed
# 654th iter completed
# 655th iter completed
# 656th iter completed
# 657th iter completed
# 658th iter completed
# 659th iter completed
# 660th iter completed
# 661th iter completed
# 662th iter completed
# 663th iter completed
# 664th iter completed
# 665th iter completed
# 666th iter completed
# 667th iter completed
# 668th iter completed
# 669th iter completed
# 670th iter completed
# 671th iter completed
# 672th iter completed
# 673th iter completed
# 674th iter completed
# 675th iter completed
# 676th iter completed
# 677th iter completed
# 678th iter completed
# 679th iter completed
# 680th iter completed
# 681th iter completed
# 682th iter completed
# 683th iter completed
# 684th iter completed
# 685th iter completed
# 686th iter completed
# 687th iter completed
# 688th iter completed
# 689th iter completed
# 690th iter completed
# 691th iter completed
# 692th iter completed
# 693th iter completed
# 694th iter completed
# 695th iter completed
# 696th iter completed
# 697th iter completed
# 698th iter completed
# 699th iter completed
# 700th iter completed
# 701th iter completed
# 702th iter completed
# 703th iter completed
# 704th iter completed
# 705th iter completed
# 706th iter completed
# 707th iter completed
# 708th iter completed
# 709th iter completed
# 710th iter completed
# 711th iter completed
# 712th iter completed
# 713th iter completed
# 714th iter completed
# 715th iter completed
# 716th iter completed
# 717th iter completed
# 718th iter completed
# 719th iter completed
# 720th iter completed
# 721th iter completed
# 722th iter completed
# 723th iter completed
# 724th iter completed
# 725th iter completed
# 726th iter completed
# 727th iter completed
# 728th iter completed
# 729th iter completed
# 730th iter completed
# 731th iter completed
# 732th iter completed
# 733th iter completed
# 734th iter completed
# 735th iter completed
# 736th iter completed
# 737th iter completed
# 738th iter completed
# 739th iter completed
# 740th iter completed
# 741th iter completed
# 742th iter completed
# 743th iter completed
# 744th iter completed
# 745th iter completed
# 746th iter completed
# 747th iter completed
# 748th iter completed
# 749th iter completed
# 750th iter completed
# 751th iter completed
# 752th iter completed
# 753th iter completed
# 754th iter completed
# 755th iter completed
# 756th iter completed
# 757th iter completed
# 758th iter completed
# 759th iter completed
# 760th iter completed
# 761th iter completed
# 762th iter completed
# 763th iter completed
# 764th iter completed
# 765th iter completed
# 766th iter completed
# 767th iter completed
# 768th iter completed
# 769th iter completed
# 770th iter completed
# 771th iter completed
# 772th iter completed
# 773th iter completed
# 774th iter completed
# 775th iter completed
# 776th iter completed
# 777th iter completed
# 778th iter completed
# 779th iter completed
# 780th iter completed
# 781th iter completed
# 782th iter completed
# 783th iter completed
# 784th iter completed
# 785th iter completed
# 786th iter completed
# 787th iter completed
# 788th iter completed
# 789th iter completed
# 790th iter completed
# 791th iter completed
# 792th iter completed
# 793th iter completed
# 794th iter completed
# 795th iter completed
# 796th iter completed
# 797th iter completed
# 798th iter completed
# 799th iter completed
# 800th iter completed
# 801th iter completed
# 802th iter completed
# 803th iter completed
# 804th iter completed
# 805th iter completed
# 806th iter completed
# 807th iter completed
# 808th iter completed
# 809th iter completed
# 810th iter completed
# 811th iter completed
# 812th iter completed
# 813th iter completed
# 814th iter completed
# 815th iter completed
# 816th iter completed
# 817th iter completed
# 818th iter completed
# 819th iter completed
# 820th iter completed
# 821th iter completed
# 822th iter completed
# 823th iter completed
# 824th iter completed
# 825th iter completed
# 826th iter completed
# 827th iter completed
# 828th iter completed
# 829th iter completed
# 830th iter completed
# 831th iter completed
# 832th iter completed
# 833th iter completed
# 834th iter completed
# 835th iter completed
# 836th iter completed
# 837th iter completed
# 838th iter completed
# 839th iter completed
# 840th iter completed
# 841th iter completed
# 842th iter completed
# 843th iter completed
# 844th iter completed
# 845th iter completed
# 846th iter completed
# 847th iter completed
# 848th iter completed
# 849th iter completed
# 850th iter completed
# 851th iter completed
# 852th iter completed
# 853th iter completed
# 854th iter completed
# 855th iter completed
# 856th iter completed
# 857th iter completed
# 858th iter completed
# 859th iter completed
# 860th iter completed
# 861th iter completed
# 862th iter completed
# 863th iter completed
# 864th iter completed
# 865th iter completed
# 866th iter completed
# 867th iter completed
# 868th iter completed
# 869th iter completed
# 870th iter completed
# 871th iter completed
# 872th iter completed
# 873th iter completed
# 874th iter completed
# 875th iter completed
# 876th iter completed
# 877th iter completed
# 878th iter completed
# 879th iter completed
# 880th iter completed
# 881th iter completed
# 882th iter completed
# 883th iter completed
# 884th iter completed
# 885th iter completed
# 886th iter completed
# 887th iter completed
# 888th iter completed
# 889th iter completed
# 890th iter completed
# 891th iter completed
# 892th iter completed
# 893th iter completed
# 894th iter completed
# 895th iter completed
# 3400th iter completed
# 3401th iter completed
# 3402th iter completed
# 3403th iter completed
# 3404th iter completed
# 3405th iter completed
# 3406th iter completed
# 3407th iter completed
# 3408th iter completed
# 3409th iter completed
# 3410th iter completed
# 3411th iter completed
# 3412th iter completed
# 3413th iter completed
# 3414th iter completed
# 3415th iter completed
# 3416th iter completed
# 3417th iter completed
# 3418th iter completed
# 3419th iter completed
# 3420th iter completed
# 3421th iter completed
# 3422th iter completed
# 3423th iter completed
# 3424th iter completed
# 3425th iter completed
# 3426th iter completed
# 3427th iter completed
# 3428th iter completed
# 3429th iter completed
# 3430th iter completed
# 3431th iter completed
# 3432th iter completed
# 3433th iter completed
# 3434th iter completed
# 3435th iter completed
# 3436th iter completed
# 3437th iter completed
# 3438th iter completed
# 3439th iter completed
# 3440th iter completed
# 3441th iter completed
# 3442th iter completed
# 3443th iter completed
# 3444th iter completed
# 3445th iter completed
# 3446th iter completed
# 3447th iter completed
# 3448th iter completed
# 3449th iter completed
# 3450th iter completed
# 3451th iter completed
# 3452th iter completed
# 3453th iter completed
# 3454th iter completed
# 3455th iter completed
# 3456th iter completed
# 3457th iter completed
# 3458th iter completed
# 3459th iter completed
# 3460th iter completed
# 3461th iter completed
# 3462th iter completed
# 3463th iter completed
# 3464th iter completed
# 3465th iter completed
# 3466th iter completed
# 3467th iter completed
# 3468th iter completed
# 3469th iter completed
# 3470th iter completed
# 3471th iter completed
# 3472th iter completed
# 3473th iter completed
# 3474th iter completed
# 3475th iter completed
# 3476th iter completed
# 3477th iter completed
# 3478th iter completed
# 3479th iter completed
# 3480th iter completed
# 3481th iter completed
# 3482th iter completed
# 3483th iter completed
# 3484th iter completed
# 3485th iter completed
# 3486th iter completed
# 3487th iter completed
# 3488th iter completed
# 3489th iter completed
# 3490th iter completed
# 3491th iter completed
# 3492th iter completed
# 3493th iter completed
# 3494th iter completed
# 3495th iter completed
# 3496th iter completed
# 3497th iter completed
# 3498th iter completed
# 3499th iter completed
# 3500th iter completed
# 3501th iter completed
# 3502th iter completed
# 3503th iter completed
# 3504th iter completed
# 3505th iter completed
# 3506th iter completed
# 3507th iter completed
# 3508th iter completed
# 3509th iter completed
# 3510th iter completed
# 3511th iter completed
# 3512th iter completed
# 3513th iter completed
# 3514th iter completed
# 3515th iter completed
# 3516th iter completed
# 3517th iter completed
# 3518th iter completed
# 3519th iter completed
# 3520th iter completed
# 3521th iter completed
# 3522th iter completed
# 3523th iter completed
# 3524th iter completed
# 3525th iter completed
# 3526th iter completed
# 3527th iter completed
# 3528th iter completed
# 3529th iter completed
# 3530th iter completed
# 3531th iter completed
# 3532th iter completed
# 3533th iter completed
# 3534th iter completed
# 3535th iter completed
# 3536th iter completed
# 3537th iter completed
# 3538th iter completed
# 3539th iter completed
# 3540th iter completed
# 3541th iter completed
# 3542th iter completed
# 3543th iter completed
# 3544th iter completed
# 3545th iter completed
# 3546th iter completed
# 3547th iter completed
# 3548th iter completed
# 3549th iter completed
# 3550th iter completed
# 3551th iter completed
# 3552th iter completed
# 3553th iter completed
# 3554th iter completed
# 3555th iter completed
# 3556th iter completed
# 3557th iter completed
# 3558th iter completed
# 3559th iter completed
# 3560th iter completed
# 3561th iter completed
# 3562th iter completed
# 3563th iter completed
# 3564th iter completed
# 3565th iter completed
# 3566th iter completed
# 3567th iter completed
# 3568th iter completed
# 3569th iter completed
# 3570th iter completed
# 3571th iter completed
# 3572th iter completed
# 3573th iter completed
# 3574th iter completed
# 3575th iter completed
# 3576th iter completed
# 3577th iter completed
# 3578th iter completed
# 3579th iter completed
# 3580th iter completed
# 3581th iter completed
# 3582th iter completed
# 3583th iter completed
# 3584th iter completed
# 3585th iter completed
# 3586th iter completed
# 3587th iter completed
# 3588th iter completed
# 3589th iter completed
# 3590th iter completed
# 3591th iter completed
# 3592th iter completed
# 3593th iter completed
# 3594th iter completed
# 3595th iter completed
# 3596th iter completed
# 3597th iter completed
# 3598th iter completed
# 3599th iter completed
# 3600th iter completed
# 3601th iter completed
# 3602th iter completed
# 3603th iter completed
# 3604th iter completed
# 3605th iter completed
# 3606th iter completed
# 3607th iter completed
# 3608th iter completed
# 3609th iter completed
# 3610th iter completed
# 3611th iter completed
# 3612th iter completed
# 3613th iter completed
# 3614th iter completed
# 3615th iter completed
# 3616th iter completed
# 3617th iter completed
# 3618th iter completed
# 3619th iter completed
# 3620th iter completed
# 3621th iter completed
# 3622th iter completed
# 3623th iter completed
# 3624th iter completed
# 3625th iter completed
# 3626th iter completed
# 3627th iter completed
# 3628th iter completed
# 3629th iter completed
# 3630th iter completed
# 3631th iter completed
# 3632th iter completed
# 3633th iter completed
# 3634th iter completed
# 3635th iter completed
# 3636th iter completed
# 3637th iter completed
# 3638th iter completed
# 3639th iter completed
# 3640th iter completed
# 3641th iter completed
# 3642th iter completed
# 3643th iter completed
# 3644th iter completed
# 3645th iter completed
# 3646th iter completed
# 3647th iter completed
# 3648th iter completed
# 3649th iter completed
# 3650th iter completed
# 3651th iter completed
# 3652th iter completed
# 3653th iter completed
# 3654th iter completed
# 3655th iter completed
# 3656th iter completed
# 3657th iter completed
# 3658th iter completed
# 3659th iter completed
# 3660th iter completed
# 3661th iter completed
# 3662th iter completed
# 3663th iter completed
# 3664th iter completed
# 3665th iter completed
# 3666th iter completed
# 3667th iter completed
# 3668th iter completed
# 3669th iter completed
# 3670th iter completed
# 3671th iter completed
# 3672th iter completed
# 3673th iter completed
# 3674th iter completed
# 3675th iter completed
# 3676th iter completed
# 3677th iter completed
# 3678th iter completed
# 3679th iter completed
# 3680th iter completed
# 3681th iter completed
# 3682th iter completed
# 3683th iter completed
# 3684th iter completed
# 3685th iter completed
# 3686th iter completed
# 3687th iter completed
# 3688th iter completed
# 3689th iter completed
# 3690th iter completed
# 3691th iter completed
# 3692th iter completed
# 3693th iter completed
# 3694th iter completed
# 3695th iter completed
# 3696th iter completed
# 3697th iter completed
# 3698th iter completed
# 3699th iter completed
# 3700th iter completed
# 3701th iter completed
# 3702th iter completed
# 3703th iter completed
# 3704th iter completed
# 3705th iter completed
# 3706th iter completed
# 3707th iter completed
# 3708th iter completed
# 3709th iter completed
# 3710th iter completed
# 3711th iter completed
# 3712th iter completed
# 3713th iter completed
# 3714th iter completed
# 3715th iter completed
# 3716th iter completed
# 3717th iter completed
# 3718th iter completed
# 3719th iter completed
# 3720th iter completed
# 3721th iter completed
# 3722th iter completed
# 3723th iter completed
# 3724th iter completed
# 3725th iter completed
# 3726th iter completed
# 3727th iter completed
# 3728th iter completed
# 3729th iter completed
# 3730th iter completed
# 3731th iter completed
# 3732th iter completed
# 3733th iter completed
# 3734th iter completed
# 3735th iter completed
# 3736th iter completed
# 3737th iter completed
# 3738th iter completed
# 3739th iter completed
# 3740th iter completed
# 3741th iter completed
# 3742th iter completed
# 3743th iter completed
# 3744th iter completed
# 3745th iter completed
# 3746th iter completed
# 3747th iter completed
# 3748th iter completed
# 3749th iter completed
# 3750th iter completed
# 3751th iter completed
# 3752th iter completed
# 3753th iter completed
# 3754th iter completed
# 3755th iter completed
# 3756th iter completed
# 3757th iter completed
# 3758th iter completed
# 3759th iter completed
# 3760th iter completed
# 3761th iter completed
# 3762th iter completed
# 3763th iter completed
# 3764th iter completed
# 3765th iter completed
# 3766th iter completed
# 3767th iter completed
# 3768th iter completed
# 3769th iter completed
# 3770th iter completed
# 3771th iter completed
# 3772th iter completed
# 3773th iter completed
# 3774th iter completed
# 3775th iter completed
# 3776th iter completed
# 3777th iter completed
# 3778th iter completed
# 3779th iter completed
# 3780th iter completed
# 3781th iter completed
# 3782th iter completed
# 3783th iter completed
# 3784th iter completed
# 3785th iter completed
# 3786th iter completed
# 3787th iter completed
# 3788th iter completed
# 3789th iter completed
# 3790th iter completed
# 3791th iter completed
# 3792th iter completed
# 3793th iter completed
# 3794th iter completed
# 3795th iter completed
# 3796th iter completed
# 3797th iter completed
# 3798th iter completed
# 3799th iter completed
# 3800th iter completed
# 3801th iter completed
# 3802th iter completed
# 3803th iter completed
# 3804th iter completed
# 3805th iter completed
# 3806th iter completed
# 3807th iter completed
# 3808th iter completed
# 3809th iter completed
# 3810th iter completed
# 3811th iter completed
# 3812th iter completed
# 3813th iter completed
# 3814th iter completed
# 3815th iter completed
# 3816th iter completed
# 3817th iter completed
# 3818th iter completed
# 3819th iter completed
# 3820th iter completed
# 3821th iter completed
# 3822th iter completed
# 3823th iter completed
# 3824th iter completed
# 3825th iter completed
# 3826th iter completed
# 3827th iter completed
# 3828th iter completed
# 3829th iter completed
# 3830th iter completed
# 3831th iter completed
# 3832th iter completed
# 3833th iter completed
# 3834th iter completed
# 3835th iter completed
# 3836th iter completed
# 3837th iter completed
# 3838th iter completed
# 3839th iter completed
# 3840th iter completed
# 3841th iter completed
# 3842th iter completed
# 3843th iter completed
# 3844th iter completed
# 3845th iter completed
# 3846th iter completed
# 3847th iter completed
# 3848th iter completed
# 3849th iter completed
# 3850th iter completed
# 3851th iter completed
# 3852th iter completed
# 3853th iter completed
# 3854th iter completed
# 3855th iter completed
# 3856th iter completed
# 3857th iter completed
# 3858th iter completed
# 3859th iter completed
# 3860th iter completed
# 3861th iter completed
# 3862th iter completed
# 3863th iter completed
# 3864th iter completed
# 3865th iter completed
# 3866th iter completed
# 3867th iter completed
# 3868th iter completed
# 3869th iter completed
# 3870th iter completed
# 3871th iter completed
# 3872th iter completed
# 3873th iter completed
# 3874th iter completed
# 3875th iter completed
# 3876th iter completed
# 3877th iter completed
# 3878th iter completed
# 3879th iter completed
# 3880th iter completed
# 3881th iter completed
# 3882th iter completed
# 3883th iter completed
# 3884th iter completed
# 3885th iter completed
# 3886th iter completed
# 3887th iter completed
# 3888th iter completed
# 3889th iter completed
# 3890th iter completed
# 3891th iter completed
# 3892th iter completed
# 3893th iter completed
# 3894th iter completed
# 3895th iter completed
# 3896th iter completed
# 3897th iter completed
# 3898th iter completed
# 3899th iter completed
# 3900th iter completed
# 3901th iter completed
# 3902th iter completed
# 3903th iter completed
# 3904th iter completed
# 3905th iter completed
# 3906th iter completed
# 3907th iter completed
# 3908th iter completed
# 3909th iter completed
# 3910th iter completed
# 3911th iter completed
# 3912th iter completed
# 3913th iter completed
# 3914th iter completed
# 3915th iter completed
# 3916th iter completed
# 3917th iter completed
# 3918th iter completed
# 3919th iter completed
# 3920th iter completed
# 3921th iter completed
# 3922th iter completed
# 3923th iter completed
# 3924th iter completed
# 3925th iter completed
# 3926th iter completed
# 3927th iter completed
# 3928th iter completed
# 3929th iter completed
# 3930th iter completed
# 3931th iter completed
# 3932th iter completed
# 3933th iter completed
# 3934th iter completed
# 3935th iter completed
# 3936th iter completed
# 3937th iter completed
# 3938th iter completed
# 3939th iter completed
# 3940th iter completed
# 3941th iter completed
# 3942th iter completed
# 3943th iter completed
# 3944th iter completed
# 3945th iter completed
# 3946th iter completed
# 3947th iter completed
# 3948th iter completed
# 3949th iter completed
# 3950th iter completed
# 3951th iter completed
# 3952th iter completed
# 3953th iter completed
# 3954th iter completed
# 3955th iter completed
# 3956th iter completed
# 3957th iter completed
# 3958th iter completed
# 3959th iter completed
# 3960th iter completed
# 3961th iter completed
# 3962th iter completed
# 3963th iter completed
# 3964th iter completed
# 3965th iter completed
# 3966th iter completed
# 3967th iter completed
# 3968th iter completed
# 3969th iter completed
# 3970th iter completed
# 3971th iter completed
# 3972th iter completed
# 3973th iter completed
# 3974th iter completed
# 3975th iter completed
# 3976th iter completed
# 3977th iter completed
# 3978th iter completed
# 3979th iter completed
# 3980th iter completed
# 3981th iter completed
# 3982th iter completed
# 3983th iter completed
# 3984th iter completed
# 3985th iter completed
# 3986th iter completed
# 3987th iter completed
# 3988th iter completed
# 3989th iter completed
# 3990th iter completed
# 3991th iter completed
# 3992th iter completed
# 3993th iter completed
# 3994th iter completed
# 3995th iter completed
# 3996th iter completed
# 3997th iter completed
# 3998th iter completed
# 3999th iter completed
# 4000th iter completed
# 4001th iter completed
# 4002th iter completed
# 4003th iter completed
# 4004th iter completed
# 4005th iter completed
# 4006th iter completed
# 4007th iter completed
# 4008th iter completed
# 4009th iter completed
# 4010th iter completed
# 4011th iter completed
# 4012th iter completed
# 4013th iter completed
# 4014th iter completed
# 4015th iter completed
# 4016th iter completed
# 4017th iter completed
# 4018th iter completed
# 4019th iter completed
# 4020th iter completed
# 4021th iter completed
# 4022th iter completed
# 4023th iter completed
# 4024th iter completed
# 4025th iter completed
# 4026th iter completed
# 4027th iter completed
# 4028th iter completed
# 4029th iter completed
# 4030th iter completed
# 4031th iter completed
# 4032th iter completed
# 4033th iter completed
# 4034th iter completed
# 4035th iter completed
# 4036th iter completed
# 4037th iter completed
# 4038th iter completed
# 4039th iter completed
# 4040th iter completed
# 4041th iter completed
# 4042th iter completed
# 4043th iter completed
# 4044th iter completed
# 4045th iter completed
# 4046th iter completed
# 4047th iter completed
# 4048th iter completed
# 4049th iter completed
# 4050th iter completed
# 4051th iter completed
# 4052th iter completed
# 4053th iter completed
# 4054th iter completed
# 4055th iter completed
# 4056th iter completed
# 4057th iter completed
# 4058th iter completed
# 4059th iter completed
# 4060th iter completed
# 4061th iter completed
# 4062th iter completed
# 4063th iter completed
# 4064th iter completed
# 4065th iter completed
# 4066th iter completed
# 4067th iter completed
# 4068th iter completed
# 4069th iter completed
# 4070th iter completed
# 4071th iter completed
# 4072th iter completed
# 4073th iter completed
# 4074th iter completed
# 4075th iter completed
# 4076th iter completed
# 4077th iter completed
# 4078th iter completed
# 4079th iter completed
# 4080th iter completed
# 4081th iter completed
# 4082th iter completed
# 4083th iter completed

# %%
# Testing process
# First, we find out the anomalous validation data
# and compute similarity score of each test data with each data within this set of anomaly validation data
# If similar enough, then regard that test image as the anomlous one as well
# When compuiting similarity score, we only compare the anomalous locations within the anomaly validation data

# If the average value of the image is larger than 0.6, then we save it as the anomaly validation image 
anomaly_idx = []
for i in range(val_image2.size()[0]):
  if torch.mean(D((torch.unsqueeze(val_image2[i,:,:], 0)).to(device))) > 0.6:
    anomaly_idx.append(i)
val_anomaly = (val_image2[anomaly_idx]).to(device)

# Anomaly locations within each anomaly validation image
anomaly_loc = torch.zeros((val_anomaly.size()[0], 1, 20))
for i in range(val_anomaly.size()[0]):
  anomaly_loc[i] = D((torch.unsqueeze(val_anomaly[i,:,:], 0)).to(device)) > 0.9
anomaly_loc = torch.squeeze(anomaly_loc,1).bool()

# Similarity Score Computation
sim_idx = []
correct_sim_idx = []
total = 0
correct = 0
for i in range(test_image2.size()[0]):
  image = (test_image2[i,0,:]).to(device)
  for j in range(val_anomaly.size()[0]):
    val = val_anomaly[j,0,:]
    
    # Regard the test image is similar to the anomaly validation iamge if
    # mean-squared difference between two images are less than 0.01
    if torch.mean(torch.square(image - val)) < 0.01:
      sim_idx.append((i, j))
      image_loc = anomaly_loc[j,:]
      check_image = image[image_loc]
      check_val = val[image_loc]
      
      # If both images (Declared to be similar according to the model) are
      # bigger than 0.5
      # or smaller than 0.5
      # (allowing marginal error)
      # then we regard this result as the correct one
      # value of 0.5 is chosen because it is the median value for the target feature
      check = (check_image-0.5)*(check_val-0.5)
      total += check.size()[0]
      check_correct = check[check>-0.0001]  # Allow the marginal error within 0.0001
      correct += check_correct.size()[0]
      if check_correct.size()[0] != 0:
          correct_sim_idx.append((i,j))
print(correct / total)
print(correct)
print(total)
# Out:
# 0.8333333333333334

# %%
result_df2 = raw_df[['ud','ma','volume']]
pred2 = pd.DataFrame(pred_list2[:,:,-1], columns=['ud','ma','volume']) * (result_df2.max(axis=0)-result_df2.min(axis=0)) + result_df2.min(axis=0)
orig2 = pd.DataFrame(orig_list2[:,:,-1], columns=['ud','ma','volume']) * (result_df2.max(axis=0)-result_df2.min(axis=0)) + result_df2.min(axis=0)

print(pred2)
print(orig2)
# Out:
#               ud          ma    volume
# 0      33.116638  300.000000  2.552225
# 1     -26.253067  -57.225845  1.200000
# 2     -80.757652    7.671753  1.224072
# 3     -48.028290   26.080078  2.843516
# 4    -150.000000  300.000000  3.513996
# ...          ...         ...       ...
# 4396  -37.459679  300.000000  2.027124
# 4397  -92.481461 -300.000000  1.308761
# 4398   21.299286  -47.648544  3.109064
# 4399  -97.034134 -300.000000  1.200000
# 4400  -48.062531 -123.967087  1.704117
#
# [4401 rows x 3 columns]
#              ud          ma    volume
# 0     16.709976  -20.219513  2.989818
# 1      8.720001   15.489502  2.468395
# 2     37.309998  -58.547516  1.462813
# 3      8.660019  -43.496002  2.285357
# 4    -86.849998 -129.641495  3.631495
# ...         ...         ...       ...
# 4396   2.419998   -9.723511  2.530834
# 4397  24.290009    9.428497  2.930780
# 4398 -57.609993   17.206512  2.843896
# 4399 -11.050003  -13.787994  1.891968
# 4400  -1.750000  -38.986511  2.448672
#
# [4401 rows x 3 columns]

# %%
# Skewedness of the distribution of predicted values are much more improved
# compared to the linear-layer-only model

print(len(orig2[orig2['ud']>0]))
print(len(orig2[orig2['ud']<0]))
print(len(pred2[pred2['ud']>0]))
print(len(pred2[pred2['ud']<0]))
# Out:
# 2188
# 2208
# 1213
# 3188

# %%
orig_big2 = orig2[orig2['ud'] > 0]
big_correct2 = 0
for i in orig_big2.index:
  if pred2.loc[i,'ud'] > -40:
    big_correct2 += 1
big_correct_rate2 = big_correct2 / len(orig_big2.index)
print(big_correct_rate2)
# Out:
# 0.48663101604278075

# %%
pred_big2 = pred2[pred2['ud'] > 40]
big_correct2 = 0
for i in pred_big2.index:
  if orig2.loc[i,'ud'] > 0:
    big_correct2 += 1
big_correct_rate2 = big_correct2 / len(pred_big2.index)
print(big_correct_rate2)
# Out:
# 0.7180544105523495

# %%
small2 = orig2[orig2['ud'] < -40]
small_correct2 = 0
for i in small2.index:
  if pred2.loc[i,'ud'] < 40:
    small_correct2 += 1
small_correct_rate2 = small_correct2 / len(small2.index)
print(small_correct_rate2)
# Out:
# 0.8748019017432647

# %%
pred_small2 = pred2[pred2['ud'] < 0]
small_correct2 = 0
for i in pred_small2.index:
  if orig2.loc[i,'ud'] < 40:
    small_correct2 += 1
small_correct_rate2 = small_correct2 / len(pred_small2.index)
print(small_correct_rate2)
# Out:
# 0.7249058971141782
